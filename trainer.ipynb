# %%
from __future__ import absolute_import, division, print_function

import math, os, random, sys, time
import cPickle, gzip
import progressbar

import numpy as np
from six.moves import xrange
import tensorflow as tf

from tensorflow.models.rnn.translate import data_utils
from tensorflow.models.rnn.translate import seq2seq_model

# %%
tf.app.flags.DEFINE_float("learning_rate", 0.5, "Learning rate.")
tf.app.flags.DEFINE_float("learning_rate_decay_factor", 0.99,
                          "Learning rate decays by this much.")
tf.app.flags.DEFINE_float("max_gradient_norm", 5.0,
                          "Clip gradients to this norm.")
tf.app.flags.DEFINE_integer("batch_size", 64,
                            "Batch size to use during training.")
tf.app.flags.DEFINE_integer("size", 600, "Size of each model layer.")
tf.app.flags.DEFINE_integer("num_layers", 3, "Number of layers in the model.")
tf.app.flags.DEFINE_integer("reactant_vocab_size", 326, "Reactant vocabulary size.")
tf.app.flags.DEFINE_integer("product_vocab_size", 197, "Product vocabulary size.")
tf.app.flags.DEFINE_string("train_dir", "/tmp", "Training directory.")
tf.app.flags.DEFINE_integer("max_train_data_size", 0,
                            "Limit on the size of training data (0: no limit).")
tf.app.flags.DEFINE_integer("steps_per_checkpoint", 200,
                            "How many training steps to do per checkpoint.")
tf.app.flags.DEFINE_boolean("decode", False,
                            "Set to True for interactive decoding.")
tf.app.flags.DEFINE_boolean("self_test", False,
                            "Run a self-test if this is set to True.")

FLAGS = tf.app.flags.FLAGS

# %%
_buckets = [(54, 54), (70, 60), (90, 65), (150, 80)]

# %%
dev_set = [[] for _ in _buckets]
train_set = [[] for _ in _buckets]

bar_dev = progressbar.ProgressBar(max_value=10942)
bar_train = progressbar.ProgressBar(max_value=1083292)

with gzip.open('data/dev.pkl.gz', 'rb') as dev_file:
    i = 1
    while 1:
        try:
            reactants, products = cPickle.load(dev_file)
            products.append(data_utils.EOS_ID)
            for bucket_id, (source_size, target_size) in enumerate(_buckets):
                if len(reactants) < source_size and len(products) < target_size:
                    dev_set[bucket_id].append([reactants, products])
                    break
        except EOFError:
            break
        bar_dev.update(i)
        i += 1

with gzip.open('data/train.pkl.gz', 'rb') as train_file:
    i = 1
    while 1:
        try:
            reactants, products = cPickle.load(train_file)
            products.append(data_utils.EOS_ID)
            for bucket_id, (source_size, target_size) in enumerate(_buckets):
                if len(reactants) < source_size and len(products) < target_size:
                    train_set[bucket_id].append([reactants, products])
                    break
        except EOFError:
            break
        bar_train.update(i)
        i += 1
        
print("dev_set size:", [len(d) for d in dev_set])
print("train_set size:", [len(t) for t in train_set])
# Out:
#  99% (1082881 of 1083292) |################ | Elapsed Time: 0:02:30 ETA: 0:00:00
# dev_set size: [3793, 2772, 2307, 2056]
# train_set size: [373867, 278092, 228864, 201503]
# 100% (1083292 of 1083292) |################| Elapsed Time: 0:02:30 ETA:  0:00:00

# %%
def create_model(session, forward_only):
    model = seq2seq_model.Seq2SeqModel(
        FLAGS.reactant_vocab_size, FLAGS.product_vocab_size, _buckets,
        FLAGS.size, FLAGS.num_layers, FLAGS.max_gradient_norm, FLAGS.batch_size,
        FLAGS.learning_rate, FLAGS.learning_rate_decay_factor,
        forward_only=forward_only)
    ckpt = tf.train.get_checkpoint_state(FLAGS.train_dir)
    if ckpt and tf.gfile.Exists(ckpt.model_checkpoint_path):
        print("Reading model parameters from %s" % ckpt.model_checkpoint_path)
        model.saver.restore(session, ckpt.model_checkpoint_path)
    else:
        print("Created model with fresh parameters.")
        session.run(tf.initialize_all_variables())
    return model

# %%
def train():
    with tf.Session() as sess:
        # Create model.
        print("Creating %d layers of %d units." % (FLAGS.num_layers, FLAGS.size))
        model = create_model(sess, False)

        # Compute bucket sizes.      
        train_bucket_sizes = [len(train_set[b]) for b in xrange(len(_buckets))]
        train_total_size = float(sum(train_bucket_sizes))

        # A bucket scale is a list of increasing numbers from 0 to 1 that we'll use
        # to select a bucket. Length of [scale[i], scale[i+1]] is proportional to
        # the size if i-th training bucket, as used later.
        train_buckets_scale = [sum(train_bucket_sizes[:i + 1]) / train_total_size
                                for i in xrange(len(train_bucket_sizes))]

        # This is the training loop.
        step_time, loss = 0.0, 0.0
        current_step = 0
        previous_losses = []
        while True:
            # Choose a bucket according to data distribution. We pick a random number
            # in [0, 1] and use the corresponding interval in train_buckets_scale.
            random_number_01 = np.random.random_sample()
            bucket_id = min([i for i in xrange(len(train_buckets_scale))
            if train_buckets_scale[i] > random_number_01])

            # Get a batch and make a step.
            start_time = time.time()
            encoder_inputs, decoder_inputs, target_weights = model.get_batch(
                      train_set, bucket_id)
            _, step_loss, _ = model.step(sess, encoder_inputs, decoder_inputs,
                                               target_weights, bucket_id, False)
            step_time += (time.time() - start_time) / FLAGS.steps_per_checkpoint
            loss += step_loss / FLAGS.steps_per_checkpoint
            current_step += 1

            # Once in a while, we save checkpoint, print statistics, and run evals.
            if current_step % FLAGS.steps_per_checkpoint == 0:
                 # Print statistics for the previous epoch.
                perplexity = math.exp(loss) if loss < 300 else float('inf')
                print ("global step %d learning rate %.4f step-time %.2f perplexity "
                        "%.2f" % (model.global_step.eval(), model.learning_rate.eval(),
                                    step_time, perplexity))
                # Decrease learning rate if no improvement was seen over last 3 times.
                if len(previous_losses) > 2 and loss > max(previous_losses[-3:]):
                    sess.run(model.learning_rate_decay_op)
                previous_losses.append(loss)
                # Save checkpoint and zero timer and loss.
                checkpoint_path = os.path.join(FLAGS.train_dir, "translate.ckpt")
                model.saver.save(sess, checkpoint_path, global_step=model.global_step)
                step_time, loss = 0.0, 0.0
                # Run evals on development set and print their perplexity.
                for bucket_id in xrange(len(_buckets)):
                    if len(dev_set[bucket_id]) == 0:
                        print("  eval: empty bucket %d" % (bucket_id))
                        continue
                    encoder_inputs, decoder_inputs, target_weights = model.get_batch(
                        dev_set, bucket_id)
                    _, eval_loss, _ = model.step(sess, encoder_inputs, decoder_inputs,
                                                    target_weights, bucket_id, True)
                    eval_ppx = math.exp(eval_loss) if eval_loss < 300 else float('inf')
                    print("  eval: bucket %d perplexity %.2f" % (bucket_id, eval_ppx))

# %%
train()
# Out:
# Creating 3 layers of 600 units.
# Created model with fresh parameters.
# global step 200 learning rate 0.5000 step-time 0.64 perplexity 24.82
#   eval: bucket 0 perplexity 10.18
#   eval: bucket 1 perplexity 9.98
#   eval: bucket 2 perplexity 11.04
#   eval: bucket 3 perplexity 11.12
# global step 400 learning rate 0.5000 step-time 0.62 perplexity 9.45
#   eval: bucket 0 perplexity 7.24
#   eval: bucket 1 perplexity 7.30
#   eval: bucket 2 perplexity 7.74
#   eval: bucket 3 perplexity 7.67
# global step 600 learning rate 0.5000 step-time 0.59 perplexity 6.76
#   eval: bucket 0 perplexity 5.51
#   eval: bucket 1 perplexity 6.06
#   eval: bucket 2 perplexity 6.27
#   eval: bucket 3 perplexity 6.69
# global step 800 learning rate 0.5000 step-time 0.61 perplexity 5.10
#   eval: bucket 0 perplexity 4.48
#   eval: bucket 1 perplexity 4.51
#   eval: bucket 2 perplexity 4.80
#   eval: bucket 3 perplexity 4.81
# global step 1000 learning rate 0.5000 step-time 0.59 perplexity 4.14
#   eval: bucket 0 perplexity 3.45
#   eval: bucket 1 perplexity 3.90
#   eval: bucket 2 perplexity 4.01
#   eval: bucket 3 perplexity 4.07
# global step 1200 learning rate 0.5000 step-time 0.65 perplexity 3.64
#   eval: bucket 0 perplexity 3.29
#   eval: bucket 1 perplexity 3.31
#   eval: bucket 2 perplexity 3.56
#   eval: bucket 3 perplexity 3.65
# global step 1400 learning rate 0.5000 step-time 0.59 perplexity 3.29
#   eval: bucket 0 perplexity 3.00
#   eval: bucket 1 perplexity 3.25
#   eval: bucket 2 perplexity 3.22
#   eval: bucket 3 perplexity 3.71
# global step 1600 learning rate 0.5000 step-time 0.61 perplexity 3.04
#   eval: bucket 0 perplexity 2.85
#   eval: bucket 1 perplexity 3.00
#   eval: bucket 2 perplexity 3.37
#   eval: bucket 3 perplexity 3.48
# global step 1800 learning rate 0.5000 step-time 0.60 perplexity 2.86
#   eval: bucket 0 perplexity 2.62
#   eval: bucket 1 perplexity 2.86
#   eval: bucket 2 perplexity 2.96
#   eval: bucket 3 perplexity 3.05
# global step 2000 learning rate 0.5000 step-time 0.62 perplexity 2.72
#   eval: bucket 0 perplexity 2.46
#   eval: bucket 1 perplexity 2.68
#   eval: bucket 2 perplexity 2.82
#   eval: bucket 3 perplexity 2.99
# global step 2200 learning rate 0.5000 step-time 0.61 perplexity 2.59
#   eval: bucket 0 perplexity 2.56
#   eval: bucket 1 perplexity 2.51
#   eval: bucket 2 perplexity 2.69
#   eval: bucket 3 perplexity 2.67
# global step 2400 learning rate 0.5000 step-time 0.60 perplexity 2.51
#   eval: bucket 0 perplexity 2.21
#   eval: bucket 1 perplexity 2.34
#   eval: bucket 2 perplexity 2.55
#   eval: bucket 3 perplexity 2.56
# global step 2600 learning rate 0.5000 step-time 0.59 perplexity 2.40
#   eval: bucket 0 perplexity 2.31
#   eval: bucket 1 perplexity 2.40
#   eval: bucket 2 perplexity 2.36
#   eval: bucket 3 perplexity 2.46
# global step 2800 learning rate 0.5000 step-time 0.62 perplexity 2.35
#   eval: bucket 0 perplexity 2.03
#   eval: bucket 1 perplexity 2.24
#   eval: bucket 2 perplexity 2.29
#   eval: bucket 3 perplexity 2.21
# global step 3000 learning rate 0.5000 step-time 0.63 perplexity 2.27
#   eval: bucket 0 perplexity 2.24
#   eval: bucket 1 perplexity 2.21
#   eval: bucket 2 perplexity 2.31
#   eval: bucket 3 perplexity 2.36
# global step 3200 learning rate 0.5000 step-time 0.61 perplexity 2.22
#   eval: bucket 0 perplexity 2.04
#   eval: bucket 1 perplexity 2.13
#   eval: bucket 2 perplexity 2.16
#   eval: bucket 3 perplexity 2.28
# global step 3400 learning rate 0.5000 step-time 0.62 perplexity 2.16
#   eval: bucket 0 perplexity 2.03
#   eval: bucket 1 perplexity 2.15
#   eval: bucket 2 perplexity 2.17
#   eval: bucket 3 perplexity 2.26
# global step 3600 learning rate 0.5000 step-time 0.64 perplexity 2.14
#   eval: bucket 0 perplexity 1.95
#   eval: bucket 1 perplexity 2.01
#   eval: bucket 2 perplexity 2.17
#   eval: bucket 3 perplexity 2.27
# global step 3800 learning rate 0.5000 step-time 0.63 perplexity 2.07
#   eval: bucket 0 perplexity 1.89
#   eval: bucket 1 perplexity 2.03
#   eval: bucket 2 perplexity 2.16
#   eval: bucket 3 perplexity 2.07
# global step 4000 learning rate 0.5000 step-time 0.62 perplexity 2.06
#   eval: bucket 0 perplexity 1.94
#   eval: bucket 1 perplexity 1.97
#   eval: bucket 2 perplexity 2.10
#   eval: bucket 3 perplexity 2.07
# global step 4200 learning rate 0.5000 step-time 0.61 perplexity 2.00
#   eval: bucket 0 perplexity 1.84
#   eval: bucket 1 perplexity 2.01
#   eval: bucket 2 perplexity 1.91
#   eval: bucket 3 perplexity 2.20
# global step 4400 learning rate 0.5000 step-time 0.61 perplexity 1.99
#   eval: bucket 0 perplexity 1.96
#   eval: bucket 1 perplexity 2.02
#   eval: bucket 2 perplexity 2.05
#   eval: bucket 3 perplexity 1.94
# global step 4600 learning rate 0.5000 step-time 0.62 perplexity 1.95
#   eval: bucket 0 perplexity 1.94
#   eval: bucket 1 perplexity 1.84
#   eval: bucket 2 perplexity 1.97
#   eval: bucket 3 perplexity 2.05
# global step 4800 learning rate 0.5000 step-time 0.61 perplexity 1.91
#   eval: bucket 0 perplexity 1.94
#   eval: bucket 1 perplexity 1.92
#   eval: bucket 2 perplexity 2.03
#   eval: bucket 3 perplexity 2.16
# global step 5000 learning rate 0.5000 step-time 0.61 perplexity 1.90
#   eval: bucket 0 perplexity 1.82
#   eval: bucket 1 perplexity 1.84
#   eval: bucket 2 perplexity 1.95
#   eval: bucket 3 perplexity 2.00
# global step 5200 learning rate 0.5000 step-time 0.62 perplexity 1.88
#   eval: bucket 0 perplexity 1.74
#   eval: bucket 1 perplexity 1.87
#   eval: bucket 2 perplexity 2.06
#   eval: bucket 3 perplexity 2.00
# global step 5400 learning rate 0.5000 step-time 0.61 perplexity 1.85
#   eval: bucket 0 perplexity 1.65
#   eval: bucket 1 perplexity 1.81
#   eval: bucket 2 perplexity 1.80
#   eval: bucket 3 perplexity 1.94
# global step 5600 learning rate 0.5000 step-time 0.61 perplexity 1.83
#   eval: bucket 0 perplexity 1.73
#   eval: bucket 1 perplexity 1.83
#   eval: bucket 2 perplexity 1.84
#   eval: bucket 3 perplexity 1.94
# global step 5800 learning rate 0.5000 step-time 0.63 perplexity 1.82
#   eval: bucket 0 perplexity 1.61
#   eval: bucket 1 perplexity 1.82
#   eval: bucket 2 perplexity 1.80
#   eval: bucket 3 perplexity 1.87
# global step 6000 learning rate 0.5000 step-time 0.61 perplexity 1.81
#   eval: bucket 0 perplexity 1.65
#   eval: bucket 1 perplexity 1.90
#   eval: bucket 2 perplexity 1.84
#   eval: bucket 3 perplexity 1.85
# global step 6200 learning rate 0.5000 step-time 0.62 perplexity 1.78
#   eval: bucket 0 perplexity 1.83
#   eval: bucket 1 perplexity 1.73
#   eval: bucket 2 perplexity 1.84
#   eval: bucket 3 perplexity 1.85
# global step 6400 learning rate 0.5000 step-time 0.63 perplexity 1.77
#   eval: bucket 0 perplexity 1.72
#   eval: bucket 1 perplexity 1.63
#   eval: bucket 2 perplexity 1.84
#   eval: bucket 3 perplexity 1.88
# global step 6600 learning rate 0.5000 step-time 0.63 perplexity 1.77
#   eval: bucket 0 perplexity 1.72
#   eval: bucket 1 perplexity 1.72
#   eval: bucket 2 perplexity 1.77
#   eval: bucket 3 perplexity 1.79
# global step 6800 learning rate 0.5000 step-time 0.63 perplexity 1.74
#   eval: bucket 0 perplexity 1.68
#   eval: bucket 1 perplexity 1.75
#   eval: bucket 2 perplexity 1.75
#   eval: bucket 3 perplexity 1.87
# global step 7000 learning rate 0.5000 step-time 0.58 perplexity 1.71
#   eval: bucket 0 perplexity 1.63
#   eval: bucket 1 perplexity 1.76
#   eval: bucket 2 perplexity 1.76
#   eval: bucket 3 perplexity 1.83
# global step 7200 learning rate 0.5000 step-time 0.62 perplexity 1.71
#   eval: bucket 0 perplexity 1.55
#   eval: bucket 1 perplexity 1.83
#   eval: bucket 2 perplexity 1.75
#   eval: bucket 3 perplexity 1.79
# global step 7400 learning rate 0.5000 step-time 0.62 perplexity 1.69
#   eval: bucket 0 perplexity 1.52
#   eval: bucket 1 perplexity 1.55
#   eval: bucket 2 perplexity 1.72
#   eval: bucket 3 perplexity 1.86
# global step 7600 learning rate 0.5000 step-time 0.61 perplexity 1.68
#   eval: bucket 0 perplexity 1.65
#   eval: bucket 1 perplexity 1.69
#   eval: bucket 2 perplexity 1.70
#   eval: bucket 3 perplexity 1.79
# global step 7800 learning rate 0.5000 step-time 0.61 perplexity 1.67
#   eval: bucket 0 perplexity 1.62
#   eval: bucket 1 perplexity 1.63
#   eval: bucket 2 perplexity 1.73
#   eval: bucket 3 perplexity 1.76
# global step 8000 learning rate 0.5000 step-time 0.59 perplexity 1.66
#   eval: bucket 0 perplexity 1.55
#   eval: bucket 1 perplexity 1.60
#   eval: bucket 2 perplexity 1.72
#   eval: bucket 3 perplexity 1.71
# global step 8200 learning rate 0.5000 step-time 0.62 perplexity 1.65
#   eval: bucket 0 perplexity 1.58
#   eval: bucket 1 perplexity 1.58
#   eval: bucket 2 perplexity 1.75
#   eval: bucket 3 perplexity 1.81
# global step 8400 learning rate 0.5000 step-time 0.61 perplexity 1.63
#   eval: bucket 0 perplexity 1.58
#   eval: bucket 1 perplexity 1.70
#   eval: bucket 2 perplexity 1.79
#   eval: bucket 3 perplexity 1.77
# global step 8600 learning rate 0.5000 step-time 0.61 perplexity 1.63
#   eval: bucket 0 perplexity 1.49
#   eval: bucket 1 perplexity 1.64
#   eval: bucket 2 perplexity 1.67
#   eval: bucket 3 perplexity 1.71
# global step 8800 learning rate 0.5000 step-time 0.61 perplexity 1.61
#   eval: bucket 0 perplexity 1.56
#   eval: bucket 1 perplexity 1.68
#   eval: bucket 2 perplexity 1.69
#   eval: bucket 3 perplexity 1.71
# global step 9000 learning rate 0.5000 step-time 0.61 perplexity 1.61
#   eval: bucket 0 perplexity 1.52
#   eval: bucket 1 perplexity 1.58
#   eval: bucket 2 perplexity 1.59
#   eval: bucket 3 perplexity 1.66
# global step 9200 learning rate 0.5000 step-time 0.63 perplexity 1.61
#   eval: bucket 0 perplexity 1.65
#   eval: bucket 1 perplexity 1.58
#   eval: bucket 2 perplexity 1.60
#   eval: bucket 3 perplexity 1.68
# global step 9400 learning rate 0.5000 step-time 0.61 perplexity 1.62
#   eval: bucket 0 perplexity 1.55
#   eval: bucket 1 perplexity 1.69
#   eval: bucket 2 perplexity 1.62
#   eval: bucket 3 perplexity 1.70
# global step 9600 learning rate 0.4950 step-time 0.60 perplexity 1.58
#   eval: bucket 0 perplexity 1.49
#   eval: bucket 1 perplexity 1.64
#   eval: bucket 2 perplexity 1.56
#   eval: bucket 3 perplexity 1.69
# global step 9800 learning rate 0.4950 step-time 0.59 perplexity 1.57
#   eval: bucket 0 perplexity 1.48
#   eval: bucket 1 perplexity 1.61
#   eval: bucket 2 perplexity 1.62
#   eval: bucket 3 perplexity 1.62
# global step 10000 learning rate 0.4950 step-time 0.63 perplexity 1.57
#   eval: bucket 0 perplexity 1.41
#   eval: bucket 1 perplexity 1.56
#   eval: bucket 2 perplexity 1.55
#   eval: bucket 3 perplexity 1.67
# global step 10200 learning rate 0.4950 step-time 0.60 perplexity 1.56
#   eval: bucket 0 perplexity 1.53
#   eval: bucket 1 perplexity 1.57
#   eval: bucket 2 perplexity 1.65
#   eval: bucket 3 perplexity 1.70
# global step 10400 learning rate 0.4950 step-time 0.59 perplexity 1.61
#   eval: bucket 0 perplexity 1.56
#   eval: bucket 1 perplexity 1.53
#   eval: bucket 2 perplexity 1.55
#   eval: bucket 3 perplexity 1.66
# global step 10600 learning rate 0.4901 step-time 0.63 perplexity 1.55
#   eval: bucket 0 perplexity 1.46
#   eval: bucket 1 perplexity 1.50
#   eval: bucket 2 perplexity 1.52
#   eval: bucket 3 perplexity 1.64
# global step 10800 learning rate 0.4901 step-time 0.60 perplexity 1.55
#   eval: bucket 0 perplexity 1.44
#   eval: bucket 1 perplexity 1.52
#   eval: bucket 2 perplexity 1.60
#   eval: bucket 3 perplexity 1.58
# global step 11000 learning rate 0.4901 step-time 0.63 perplexity 1.54
#   eval: bucket 0 perplexity 1.51
#   eval: bucket 1 perplexity 1.52
#   eval: bucket 2 perplexity 1.59
#   eval: bucket 3 perplexity 1.48
# global step 11200 learning rate 0.4901 step-time 0.63 perplexity 1.53
#   eval: bucket 0 perplexity 1.39
#   eval: bucket 1 perplexity 1.51
#   eval: bucket 2 perplexity 1.56
#   eval: bucket 3 perplexity 1.61
# global step 11400 learning rate 0.4901 step-time 0.60 perplexity 1.52
#   eval: bucket 0 perplexity 1.48
#   eval: bucket 1 perplexity 1.47
#   eval: bucket 2 perplexity 1.63
#   eval: bucket 3 perplexity 1.62
# global step 11600 learning rate 0.4901 step-time 0.62 perplexity 1.52
#   eval: bucket 0 perplexity 1.53
#   eval: bucket 1 perplexity 1.55
#   eval: bucket 2 perplexity 1.58
#   eval: bucket 3 perplexity 1.70
# global step 11800 learning rate 0.4901 step-time 0.60 perplexity 1.50
#   eval: bucket 0 perplexity 1.42
#   eval: bucket 1 perplexity 1.50
#   eval: bucket 2 perplexity 1.62
#   eval: bucket 3 perplexity 1.52
# global step 12000 learning rate 0.4901 step-time 0.60 perplexity 1.50
#   eval: bucket 0 perplexity 1.45
#   eval: bucket 1 perplexity 1.50
#   eval: bucket 2 perplexity 1.56
#   eval: bucket 3 perplexity 1.59
# global step 12200 learning rate 0.4901 step-time 0.62 perplexity 1.50
#   eval: bucket 0 perplexity 1.50
#   eval: bucket 1 perplexity 1.61
#   eval: bucket 2 perplexity 1.52
#   eval: bucket 3 perplexity 1.67
# global step 12400 learning rate 0.4901 step-time 0.60 perplexity 1.50
#   eval: bucket 0 perplexity 1.42
#   eval: bucket 1 perplexity 1.45
#   eval: bucket 2 perplexity 1.50
#   eval: bucket 3 perplexity 1.60
# global step 12600 learning rate 0.4901 step-time 0.60 perplexity 1.48
#   eval: bucket 0 perplexity 1.44
#   eval: bucket 1 perplexity 1.48
#   eval: bucket 2 perplexity 1.44
#   eval: bucket 3 perplexity 1.56
# global step 12800 learning rate 0.4901 step-time 0.60 perplexity 1.48
#   eval: bucket 0 perplexity 1.37
#   eval: bucket 1 perplexity 1.48
#   eval: bucket 2 perplexity 1.48
#   eval: bucket 3 perplexity 1.51
# global step 13000 learning rate 0.4901 step-time 0.63 perplexity 1.48
#   eval: bucket 0 perplexity 1.45
#   eval: bucket 1 perplexity 1.47
#   eval: bucket 2 perplexity 1.50
#   eval: bucket 3 perplexity 1.59
# global step 13200 learning rate 0.4901 step-time 0.62 perplexity 1.48
#   eval: bucket 0 perplexity 1.43
#   eval: bucket 1 perplexity 1.57
#   eval: bucket 2 perplexity 1.53
#   eval: bucket 3 perplexity 1.56
# global step 13400 learning rate 0.4901 step-time 0.62 perplexity 1.47
#   eval: bucket 0 perplexity 1.45
#   eval: bucket 1 perplexity 1.51
#   eval: bucket 2 perplexity 1.47
#   eval: bucket 3 perplexity 1.63
# global step 13600 learning rate 0.4901 step-time 0.63 perplexity 1.50
#   eval: bucket 0 perplexity 1.44
#   eval: bucket 1 perplexity 1.52
#   eval: bucket 2 perplexity 1.54
#   eval: bucket 3 perplexity 1.52
# global step 13800 learning rate 0.4851 step-time 0.61 perplexity 1.46
#   eval: bucket 0 perplexity 1.44
#   eval: bucket 1 perplexity 1.48
#   eval: bucket 2 perplexity 1.47
#   eval: bucket 3 perplexity 1.47
# global step 14000 learning rate 0.4851 step-time 0.61 perplexity 1.46
#   eval: bucket 0 perplexity 1.33
#   eval: bucket 1 perplexity 1.39
#   eval: bucket 2 perplexity 1.51
#   eval: bucket 3 perplexity 1.56
# global step 14200 learning rate 0.4851 step-time 0.59 perplexity 1.45
#   eval: bucket 0 perplexity 1.48
#   eval: bucket 1 perplexity 1.44
#   eval: bucket 2 perplexity 1.61
#   eval: bucket 3 perplexity 1.51
# global step 14400 learning rate 0.4851 step-time 0.61 perplexity 1.45
#   eval: bucket 0 perplexity 1.42
#   eval: bucket 1 perplexity 1.49
#   eval: bucket 2 perplexity 1.53
#   eval: bucket 3 perplexity 1.48
# global step 14600 learning rate 0.4851 step-time 0.59 perplexity 1.44
#   eval: bucket 0 perplexity 1.39
#   eval: bucket 1 perplexity 1.49
#   eval: bucket 2 perplexity 1.53
#   eval: bucket 3 perplexity 1.50
# global step 14800 learning rate 0.4851 step-time 0.61 perplexity 1.44
#   eval: bucket 0 perplexity 1.41
#   eval: bucket 1 perplexity 1.42
#   eval: bucket 2 perplexity 1.61
#   eval: bucket 3 perplexity 1.47
# global step 15000 learning rate 0.4851 step-time 0.61 perplexity 1.45
#   eval: bucket 0 perplexity 1.34
#   eval: bucket 1 perplexity 1.40
#   eval: bucket 2 perplexity 1.50
#   eval: bucket 3 perplexity 1.45
# global step 15200 learning rate 0.4803 step-time 0.62 perplexity 1.44
#   eval: bucket 0 perplexity 1.32
#   eval: bucket 1 perplexity 1.43
#   eval: bucket 2 perplexity 1.48
#   eval: bucket 3 perplexity 1.49
# global step 15400 learning rate 0.4803 step-time 0.61 perplexity 1.43
#   eval: bucket 0 perplexity 1.42
#   eval: bucket 1 perplexity 1.39
#   eval: bucket 2 perplexity 1.51
#   eval: bucket 3 perplexity 1.50
# global step 15600 learning rate 0.4803 step-time 0.62 perplexity 1.43
#   eval: bucket 0 perplexity 1.33
#   eval: bucket 1 perplexity 1.39
#   eval: bucket 2 perplexity 1.45
#   eval: bucket 3 perplexity 1.45
# global step 15800 learning rate 0.4803 step-time 0.60 perplexity 1.42
#   eval: bucket 0 perplexity 1.34
#   eval: bucket 1 perplexity 1.46
#   eval: bucket 2 perplexity 1.50
#   eval: bucket 3 perplexity 1.49
# global step 16000 learning rate 0.4803 step-time 0.60 perplexity 1.42
#   eval: bucket 0 perplexity 1.35
#   eval: bucket 1 perplexity 1.38
#   eval: bucket 2 perplexity 1.45
#   eval: bucket 3 perplexity 1.47
# global step 16200 learning rate 0.4803 step-time 0.61 perplexity 1.42
#   eval: bucket 0 perplexity 1.35
#   eval: bucket 1 perplexity 1.41
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 1.53
# global step 16400 learning rate 0.4803 step-time 0.62 perplexity 1.42
#   eval: bucket 0 perplexity 1.42
#   eval: bucket 1 perplexity 1.41
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 1.44
# global step 16600 learning rate 0.4803 step-time 0.59 perplexity 1.41
#   eval: bucket 0 perplexity 1.37
#   eval: bucket 1 perplexity 1.45
#   eval: bucket 2 perplexity 1.45
#   eval: bucket 3 perplexity 1.51
# global step 16800 learning rate 0.4803 step-time 0.62 perplexity 1.41
#   eval: bucket 0 perplexity 1.31
#   eval: bucket 1 perplexity 1.42
#   eval: bucket 2 perplexity 1.46
#   eval: bucket 3 perplexity 1.41
# global step 17000 learning rate 0.4803 step-time 0.64 perplexity 1.41
#   eval: bucket 0 perplexity 1.33
#   eval: bucket 1 perplexity 1.35
#   eval: bucket 2 perplexity 1.41
#   eval: bucket 3 perplexity 1.48
# global step 17200 learning rate 0.4803 step-time 0.61 perplexity 1.40
#   eval: bucket 0 perplexity 1.33
#   eval: bucket 1 perplexity 1.47
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 1.53
# global step 17400 learning rate 0.4803 step-time 0.62 perplexity 1.40
#   eval: bucket 0 perplexity 1.35
#   eval: bucket 1 perplexity 1.40
#   eval: bucket 2 perplexity 1.44
#   eval: bucket 3 perplexity 1.43
# global step 17600 learning rate 0.4803 step-time 0.62 perplexity 1.39
#   eval: bucket 0 perplexity 1.39
#   eval: bucket 1 perplexity 1.39
#   eval: bucket 2 perplexity 1.39
#   eval: bucket 3 perplexity 1.42
# global step 17800 learning rate 0.4803 step-time 0.60 perplexity 1.40
#   eval: bucket 0 perplexity 1.29
#   eval: bucket 1 perplexity 1.42
#   eval: bucket 2 perplexity 1.43
#   eval: bucket 3 perplexity 1.51
# global step 18000 learning rate 0.4803 step-time 0.64 perplexity 1.40
#   eval: bucket 0 perplexity 1.39
#   eval: bucket 1 perplexity 1.37
#   eval: bucket 2 perplexity 1.40
#   eval: bucket 3 perplexity 1.45
# global step 18200 learning rate 0.4755 step-time 0.60 perplexity 1.38
#   eval: bucket 0 perplexity 1.32
#   eval: bucket 1 perplexity 1.46
#   eval: bucket 2 perplexity 1.38
#   eval: bucket 3 perplexity 1.39
# global step 18400 learning rate 0.4755 step-time 0.59 perplexity 1.38
#   eval: bucket 0 perplexity 1.32
#   eval: bucket 1 perplexity 1.31
#   eval: bucket 2 perplexity 1.39
#   eval: bucket 3 perplexity 1.51
# global step 18600 learning rate 0.4755 step-time 0.62 perplexity 1.38
#   eval: bucket 0 perplexity 1.41
#   eval: bucket 1 perplexity 1.34
#   eval: bucket 2 perplexity 1.40
#   eval: bucket 3 perplexity 1.44
# global step 18800 learning rate 0.4755 step-time 0.61 perplexity 1.38
#   eval: bucket 0 perplexity 1.34
#   eval: bucket 1 perplexity 1.33
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 1.51
# global step 19000 learning rate 0.4755 step-time 0.61 perplexity 1.37
#   eval: bucket 0 perplexity 1.37
#   eval: bucket 1 perplexity 1.36
#   eval: bucket 2 perplexity 1.40
#   eval: bucket 3 perplexity 1.46
# global step 19200 learning rate 0.4755 step-time 0.61 perplexity 1.37
#   eval: bucket 0 perplexity 1.40
#   eval: bucket 1 perplexity 1.39
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 1.44
# global step 19400 learning rate 0.4755 step-time 0.61 perplexity 1.37
#   eval: bucket 0 perplexity 1.34
#   eval: bucket 1 perplexity 1.43
#   eval: bucket 2 perplexity 1.49
#   eval: bucket 3 perplexity 1.48
# global step 19600 learning rate 0.4755 step-time 0.59 perplexity 1.36
#   eval: bucket 0 perplexity 1.33
#   eval: bucket 1 perplexity 1.34
#   eval: bucket 2 perplexity 1.39
#   eval: bucket 3 perplexity 1.42
# global step 19800 learning rate 0.4755 step-time 0.60 perplexity 1.36
#   eval: bucket 0 perplexity 1.30
#   eval: bucket 1 perplexity 1.39
#   eval: bucket 2 perplexity 1.39
#   eval: bucket 3 perplexity 1.46
# global step 20000 learning rate 0.4755 step-time 0.62 perplexity 1.36
#   eval: bucket 0 perplexity 1.29
#   eval: bucket 1 perplexity 1.36
#   eval: bucket 2 perplexity 1.43
#   eval: bucket 3 perplexity 1.46
# global step 20200 learning rate 0.4755 step-time 0.60 perplexity 1.36
#   eval: bucket 0 perplexity 1.28
#   eval: bucket 1 perplexity 1.36
#   eval: bucket 2 perplexity 1.37
#   eval: bucket 3 perplexity 1.43
# global step 20400 learning rate 0.4755 step-time 0.60 perplexity 1.36
#   eval: bucket 0 perplexity 1.28
#   eval: bucket 1 perplexity 1.37
#   eval: bucket 2 perplexity 1.41
#   eval: bucket 3 perplexity 1.43
# global step 20600 learning rate 0.4755 step-time 0.62 perplexity 1.36
#   eval: bucket 0 perplexity 1.34
#   eval: bucket 1 perplexity 1.36
#   eval: bucket 2 perplexity 1.45
#   eval: bucket 3 perplexity 1.45
# global step 20800 learning rate 0.4755 step-time 0.62 perplexity 1.36
#   eval: bucket 0 perplexity 1.33
#   eval: bucket 1 perplexity 1.35
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 1.41
# global step 21000 learning rate 0.4755 step-time 0.61 perplexity 1.35
#   eval: bucket 0 perplexity 1.31
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.38
#   eval: bucket 3 perplexity 1.42
# global step 21200 learning rate 0.4755 step-time 0.60 perplexity 1.35
#   eval: bucket 0 perplexity 1.30
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.41
#   eval: bucket 3 perplexity 1.40
# global step 21400 learning rate 0.4755 step-time 0.63 perplexity 1.35
#   eval: bucket 0 perplexity 1.31
#   eval: bucket 1 perplexity 1.38
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 1.43
# global step 21600 learning rate 0.4755 step-time 0.61 perplexity 1.35
#   eval: bucket 0 perplexity 1.35
#   eval: bucket 1 perplexity 1.39
#   eval: bucket 2 perplexity 1.38
#   eval: bucket 3 perplexity 1.38
# global step 21800 learning rate 0.4755 step-time 0.60 perplexity 1.34
#   eval: bucket 0 perplexity 1.32
#   eval: bucket 1 perplexity 1.35
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 1.37
# global step 22000 learning rate 0.4755 step-time 0.60 perplexity 1.34
#   eval: bucket 0 perplexity 1.43
#   eval: bucket 1 perplexity 1.33
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 1.36
# global step 22200 learning rate 0.4755 step-time 0.60 perplexity 1.34
#   eval: bucket 0 perplexity 1.28
#   eval: bucket 1 perplexity 1.34
#   eval: bucket 2 perplexity 1.40
#   eval: bucket 3 perplexity 1.45
# global step 22400 learning rate 0.4755 step-time 0.60 perplexity 1.33
#   eval: bucket 0 perplexity 1.35
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.41
#   eval: bucket 3 perplexity 1.37
# global step 22600 learning rate 0.4755 step-time 0.60 perplexity 1.33
#   eval: bucket 0 perplexity 1.29
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 1.37
# global step 22800 learning rate 0.4755 step-time 0.61 perplexity 1.33
#   eval: bucket 0 perplexity 1.31
#   eval: bucket 1 perplexity 1.34
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 1.39
# global step 23000 learning rate 0.4755 step-time 0.63 perplexity 1.33
#   eval: bucket 0 perplexity 1.31
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 1.35
# global step 23200 learning rate 0.4707 step-time 0.59 perplexity 1.33
#   eval: bucket 0 perplexity 1.28
#   eval: bucket 1 perplexity 1.30
#   eval: bucket 2 perplexity 1.36
#   eval: bucket 3 perplexity 1.41
# global step 23400 learning rate 0.4707 step-time 0.61 perplexity 1.32
#   eval: bucket 0 perplexity 1.27
#   eval: bucket 1 perplexity 1.34
#   eval: bucket 2 perplexity 1.41
#   eval: bucket 3 perplexity 1.36
# global step 23600 learning rate 0.4707 step-time 0.60 perplexity 1.32
#   eval: bucket 0 perplexity 1.26
#   eval: bucket 1 perplexity 1.30
#   eval: bucket 2 perplexity 1.43
#   eval: bucket 3 perplexity 1.41
# global step 23800 learning rate 0.4707 step-time 0.62 perplexity 1.32
#   eval: bucket 0 perplexity 1.33
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.35
#   eval: bucket 3 perplexity 1.37
# global step 24000 learning rate 0.4707 step-time 0.59 perplexity 1.31
#   eval: bucket 0 perplexity 1.32
#   eval: bucket 1 perplexity 1.35
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 1.37
# global step 24200 learning rate 0.4707 step-time 0.65 perplexity 1.33
#   eval: bucket 0 perplexity 1.34
#   eval: bucket 1 perplexity 1.31
#   eval: bucket 2 perplexity 1.40
#   eval: bucket 3 perplexity 1.39
# global step 24400 learning rate 0.4660 step-time 0.60 perplexity 1.32
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.36
#   eval: bucket 2 perplexity 1.35
#   eval: bucket 3 perplexity 1.43
# global step 24600 learning rate 0.4660 step-time 0.62 perplexity 1.32
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.33
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 1.40
# global step 24800 learning rate 0.4660 step-time 0.62 perplexity 1.32
#   eval: bucket 0 perplexity 1.27
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 1.38
# global step 25000 learning rate 0.4660 step-time 0.61 perplexity 1.31
#   eval: bucket 0 perplexity 1.33
#   eval: bucket 1 perplexity 1.30
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 1.41
# global step 25200 learning rate 0.4660 step-time 0.60 perplexity 1.31
#   eval: bucket 0 perplexity 1.26
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 1.45
# global step 25400 learning rate 0.4660 step-time 0.60 perplexity 1.31
#   eval: bucket 0 perplexity 1.28
#   eval: bucket 1 perplexity 1.34
#   eval: bucket 2 perplexity 1.36
#   eval: bucket 3 perplexity 1.36
# global step 25600 learning rate 0.4660 step-time 0.61 perplexity 1.32
#   eval: bucket 0 perplexity 1.32
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 1.39
# global step 25800 learning rate 0.4614 step-time 0.64 perplexity 1.32
#   eval: bucket 0 perplexity 1.26
#   eval: bucket 1 perplexity 1.37
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 1.38
# global step 26000 learning rate 0.4614 step-time 0.62 perplexity 1.30
#   eval: bucket 0 perplexity 1.33
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 1.37
# global step 26200 learning rate 0.4614 step-time 0.58 perplexity 1.30
#   eval: bucket 0 perplexity 1.28
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.39
#   eval: bucket 3 perplexity 1.37
# global step 26400 learning rate 0.4614 step-time 0.63 perplexity 1.31
#   eval: bucket 0 perplexity 1.27
#   eval: bucket 1 perplexity 1.34
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 1.35
# global step 26600 learning rate 0.4614 step-time 0.61 perplexity 1.30
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.29
#   eval: bucket 3 perplexity 1.33
# global step 26800 learning rate 0.4614 step-time 0.62 perplexity 1.30
#   eval: bucket 0 perplexity 1.28
#   eval: bucket 1 perplexity 1.30
#   eval: bucket 2 perplexity 1.37
#   eval: bucket 3 perplexity 1.35
# global step 27000 learning rate 0.4614 step-time 0.60 perplexity 1.30
#   eval: bucket 0 perplexity 1.28
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 1.35
# global step 27200 learning rate 0.4614 step-time 0.62 perplexity 1.30
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.33
#   eval: bucket 2 perplexity 1.38
#   eval: bucket 3 perplexity 1.43
# global step 27400 learning rate 0.4614 step-time 0.60 perplexity 1.29
#   eval: bucket 0 perplexity 1.30
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.39
#   eval: bucket 3 perplexity 1.30
# global step 27600 learning rate 0.4614 step-time 0.60 perplexity 1.29
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.31
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 1.44
# global step 27800 learning rate 0.4614 step-time 0.62 perplexity 1.29
#   eval: bucket 0 perplexity 1.33
#   eval: bucket 1 perplexity 1.30
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 1.40
# global step 28000 learning rate 0.4614 step-time 0.60 perplexity 1.29
#   eval: bucket 0 perplexity 1.29
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 1.37
# global step 28200 learning rate 0.4614 step-time 0.63 perplexity 1.29
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.30
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 1.29
# global step 28400 learning rate 0.4614 step-time 0.61 perplexity 1.29
#   eval: bucket 0 perplexity 1.26
#   eval: bucket 1 perplexity 1.30
#   eval: bucket 2 perplexity 1.35
#   eval: bucket 3 perplexity 1.32
# global step 28600 learning rate 0.4614 step-time 0.61 perplexity 1.29
#   eval: bucket 0 perplexity 1.23
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 1.30
# global step 28800 learning rate 0.4614 step-time 0.64 perplexity 1.29
#   eval: bucket 0 perplexity 1.33
#   eval: bucket 1 perplexity 1.37
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 1.33
# global step 29000 learning rate 0.4614 step-time 0.60 perplexity 1.32
#   eval: bucket 0 perplexity 1.32
#   eval: bucket 1 perplexity 1.37
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 1.35
# global step 29200 learning rate 0.4568 step-time 0.64 perplexity 1.29
#   eval: bucket 0 perplexity 1.32
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.35
#   eval: bucket 3 perplexity 1.33
# global step 29400 learning rate 0.4568 step-time 0.63 perplexity 1.28
#   eval: bucket 0 perplexity 1.26
#   eval: bucket 1 perplexity 1.29
#   eval: bucket 2 perplexity 1.36
#   eval: bucket 3 perplexity 1.34
# global step 29600 learning rate 0.4568 step-time 0.60 perplexity 1.28
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 1.37
# global step 29800 learning rate 0.4568 step-time 0.61 perplexity 1.28
#   eval: bucket 0 perplexity 1.28
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.39
#   eval: bucket 3 perplexity 1.30
# global step 30000 learning rate 0.4568 step-time 0.60 perplexity 1.28
#   eval: bucket 0 perplexity 1.26
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.33
# global step 30200 learning rate 0.4568 step-time 0.62 perplexity 1.28
#   eval: bucket 0 perplexity 1.27
#   eval: bucket 1 perplexity 1.29
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 1.30
# global step 30400 learning rate 0.4522 step-time 0.63 perplexity 1.28
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.29
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 1.34
# global step 30600 learning rate 0.4522 step-time 0.58 perplexity 1.27
#   eval: bucket 0 perplexity 1.23
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.42
# global step 30800 learning rate 0.4522 step-time 0.62 perplexity 1.27
#   eval: bucket 0 perplexity 1.29
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.41
# global step 31000 learning rate 0.4522 step-time 0.62 perplexity 1.27
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.35
# global step 31200 learning rate 0.4522 step-time 0.61 perplexity 1.27
#   eval: bucket 0 perplexity 1.30
#   eval: bucket 1 perplexity 1.31
#   eval: bucket 2 perplexity 1.36
#   eval: bucket 3 perplexity 1.31
# global step 31400 learning rate 0.4522 step-time 0.62 perplexity 1.27
#   eval: bucket 0 perplexity 1.29
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 1.39
# global step 31600 learning rate 0.4477 step-time 0.62 perplexity 1.27
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.38
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 1.30
# global step 31800 learning rate 0.4477 step-time 0.59 perplexity 1.27
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.29
#   eval: bucket 3 perplexity 1.30
# global step 32000 learning rate 0.4477 step-time 0.63 perplexity 1.27
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 1.32
# global step 32200 learning rate 0.4477 step-time 0.60 perplexity 1.27
#   eval: bucket 0 perplexity 1.26
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.38
# global step 32400 learning rate 0.4477 step-time 0.62 perplexity 1.26
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 1.38
# global step 32600 learning rate 0.4477 step-time 0.63 perplexity 1.26
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.32
# global step 32800 learning rate 0.4477 step-time 0.63 perplexity 1.27
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 1.32
# global step 33000 learning rate 0.4432 step-time 0.59 perplexity 1.26
#   eval: bucket 0 perplexity 1.26
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.41
# global step 33200 learning rate 0.4432 step-time 0.61 perplexity 1.26
#   eval: bucket 0 perplexity 1.28
#   eval: bucket 1 perplexity 1.30
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 1.37
# global step 33400 learning rate 0.4432 step-time 0.59 perplexity 1.26
#   eval: bucket 0 perplexity 1.29
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 1.40
# global step 33600 learning rate 0.4432 step-time 0.65 perplexity 1.27
#   eval: bucket 0 perplexity 1.30
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.31
# global step 33800 learning rate 0.4388 step-time 0.62 perplexity 1.26
#   eval: bucket 0 perplexity 1.26
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 1.27
# global step 34000 learning rate 0.4388 step-time 0.61 perplexity 1.25
#   eval: bucket 0 perplexity 1.35
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 1.44
# global step 34200 learning rate 0.4388 step-time 0.62 perplexity 1.25
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 1.35
# global step 34400 learning rate 0.4388 step-time 0.62 perplexity 1.26
#   eval: bucket 0 perplexity 1.27
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 1.40
# global step 34600 learning rate 0.4388 step-time 0.62 perplexity 1.25
#   eval: bucket 0 perplexity 1.23
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 1.33
# global step 34800 learning rate 0.4388 step-time 0.63 perplexity 1.26
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 1.39
# global step 35000 learning rate 0.4344 step-time 0.61 perplexity 1.25
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.28
# global step 35200 learning rate 0.4344 step-time 0.63 perplexity 1.26
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.31
# global step 35400 learning rate 0.4344 step-time 0.62 perplexity 1.25
#   eval: bucket 0 perplexity 1.23
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 1.35
# global step 35600 learning rate 0.4344 step-time 0.63 perplexity 1.25
#   eval: bucket 0 perplexity 1.26
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.38
# global step 35800 learning rate 0.4344 step-time 0.62 perplexity 1.25
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.30
#   eval: bucket 2 perplexity 1.29
#   eval: bucket 3 perplexity 1.28
# global step 36000 learning rate 0.4344 step-time 0.61 perplexity 1.24
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 1.34
# global step 36200 learning rate 0.4344 step-time 0.61 perplexity 1.25
#   eval: bucket 0 perplexity 1.23
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 1.31
# global step 36400 learning rate 0.4300 step-time 0.61 perplexity 1.25
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.32
# global step 36600 learning rate 0.4300 step-time 0.61 perplexity 1.24
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.39
# global step 36800 learning rate 0.4300 step-time 0.62 perplexity 1.25
#   eval: bucket 0 perplexity 1.26
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.30
# global step 37000 learning rate 0.4257 step-time 0.63 perplexity 1.24
#   eval: bucket 0 perplexity 1.23
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.26
# global step 37200 learning rate 0.4257 step-time 0.61 perplexity 1.24
#   eval: bucket 0 perplexity 1.29
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.27
# global step 37400 learning rate 0.4257 step-time 0.59 perplexity 1.23
#   eval: bucket 0 perplexity 1.28
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.32
# global step 37600 learning rate 0.4257 step-time 0.61 perplexity 1.24
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.29
# global step 37800 learning rate 0.4257 step-time 0.60 perplexity 1.23
#   eval: bucket 0 perplexity 1.23
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.37
# global step 38000 learning rate 0.4257 step-time 0.59 perplexity 1.24
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.31
# global step 38200 learning rate 0.4257 step-time 0.62 perplexity 1.24
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 1.31
# global step 38400 learning rate 0.4257 step-time 0.61 perplexity 1.24
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.30
# global step 38600 learning rate 0.4257 step-time 0.60 perplexity 1.24
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.30
# global step 38800 learning rate 0.4257 step-time 0.61 perplexity 1.24
#   eval: bucket 0 perplexity 1.22
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.26
# global step 39000 learning rate 0.4257 step-time 0.61 perplexity 1.24
#   eval: bucket 0 perplexity 1.22
#   eval: bucket 1 perplexity 1.31
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 1.36
# global step 39200 learning rate 0.4257 step-time 0.61 perplexity 1.23
#   eval: bucket 0 perplexity 1.22
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.29
# global step 39400 learning rate 0.4257 step-time 0.61 perplexity 1.23
#   eval: bucket 0 perplexity 1.22
#   eval: bucket 1 perplexity 1.33
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.34
# global step 39600 learning rate 0.4257 step-time 0.61 perplexity 1.23
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.30
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.31
# global step 39800 learning rate 0.4257 step-time 0.62 perplexity 1.24
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.35
# global step 40000 learning rate 0.4215 step-time 0.63 perplexity 1.24
#   eval: bucket 0 perplexity 1.27
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.31
# global step 40200 learning rate 0.4215 step-time 0.62 perplexity 1.23
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.31
# global step 40400 learning rate 0.4215 step-time 0.62 perplexity 1.23
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 1.27
# global step 40600 learning rate 0.4215 step-time 0.60 perplexity 1.23
#   eval: bucket 0 perplexity 1.23
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 1.28
# global step 40800 learning rate 0.4215 step-time 0.65 perplexity 1.23
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.29
#   eval: bucket 3 perplexity 1.30
# global step 41000 learning rate 0.4173 step-time 0.62 perplexity 1.23
#   eval: bucket 0 perplexity 1.32
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.26
# global step 41200 learning rate 0.4173 step-time 0.60 perplexity 1.23
#   eval: bucket 0 perplexity 1.23
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.29
#   eval: bucket 3 perplexity 1.26
# global step 41400 learning rate 0.4173 step-time 0.61 perplexity 1.23
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.35
# global step 41600 learning rate 0.4173 step-time 0.61 perplexity 1.22
#   eval: bucket 0 perplexity 1.23
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.29
# global step 41800 learning rate 0.4173 step-time 0.61 perplexity 1.23
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.26
# global step 42000 learning rate 0.4173 step-time 0.61 perplexity 1.22
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.35
# global step 42200 learning rate 0.4173 step-time 0.58 perplexity 1.22
#   eval: bucket 0 perplexity 1.22
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.29
#   eval: bucket 3 perplexity 1.26
# global step 42400 learning rate 0.4173 step-time 0.60 perplexity 1.22
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.36
# global step 42600 learning rate 0.4173 step-time 0.60 perplexity 1.22
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.35
# global step 42800 learning rate 0.4173 step-time 0.62 perplexity 1.22
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.26
# global step 43000 learning rate 0.4173 step-time 0.60 perplexity 1.21
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.26
# global step 43200 learning rate 0.4173 step-time 0.63 perplexity 1.22
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.26
# global step 43400 learning rate 0.4173 step-time 0.61 perplexity 1.22
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.29
#   eval: bucket 3 perplexity 1.28
# global step 43600 learning rate 0.4173 step-time 0.60 perplexity 1.22
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.28
# global step 43800 learning rate 0.4173 step-time 0.59 perplexity 1.22
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.22
# global step 44000 learning rate 0.4173 step-time 0.61 perplexity 1.21
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.28
# global step 44200 learning rate 0.4173 step-time 0.61 perplexity 1.22
#   eval: bucket 0 perplexity 1.22
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.27
# global step 44400 learning rate 0.4173 step-time 0.65 perplexity 1.22
#   eval: bucket 0 perplexity 1.27
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.21
# global step 44600 learning rate 0.4173 step-time 0.59 perplexity 1.21
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.25
# global step 44800 learning rate 0.4173 step-time 0.62 perplexity 1.22
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.25
# global step 45000 learning rate 0.4173 step-time 0.61 perplexity 1.22
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.26
# global step 45200 learning rate 0.4173 step-time 0.63 perplexity 1.24
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.33
# global step 45400 learning rate 0.4131 step-time 0.61 perplexity 1.21
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.31
# global step 45600 learning rate 0.4131 step-time 0.62 perplexity 1.21
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.30
# global step 45800 learning rate 0.4131 step-time 0.61 perplexity 1.21
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.27
# global step 46000 learning rate 0.4131 step-time 0.61 perplexity 1.21
#   eval: bucket 0 perplexity 1.26
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.33
# global step 46200 learning rate 0.4131 step-time 0.61 perplexity 1.21
#   eval: bucket 0 perplexity 1.22
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.26
# global step 46400 learning rate 0.4131 step-time 0.63 perplexity 1.21
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.28
# global step 46600 learning rate 0.4131 step-time 0.62 perplexity 1.21
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.34
# global step 46800 learning rate 0.4131 step-time 0.60 perplexity 1.21
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 1.24
# global step 47000 learning rate 0.4131 step-time 0.60 perplexity 1.20
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.28
# global step 47200 learning rate 0.4131 step-time 0.65 perplexity 1.21
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.28
# global step 47400 learning rate 0.4090 step-time 0.62 perplexity 1.21
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.26
# global step 47600 learning rate 0.4090 step-time 0.62 perplexity 1.21
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.28
# global step 47800 learning rate 0.4049 step-time 0.60 perplexity 1.20
#   eval: bucket 0 perplexity 1.22
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.23
# global step 48000 learning rate 0.4049 step-time 0.62 perplexity 1.20
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.25
# global step 48200 learning rate 0.4049 step-time 0.59 perplexity 1.20
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.25
# global step 48400 learning rate 0.4049 step-time 0.61 perplexity 1.20
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.24
# global step 48600 learning rate 0.4049 step-time 0.61 perplexity 1.20
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.26
# global step 48800 learning rate 0.4049 step-time 0.61 perplexity 1.20
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.25
# global step 49000 learning rate 0.4049 step-time 0.60 perplexity 1.20
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.28
# global step 49200 learning rate 0.4049 step-time 0.61 perplexity 1.20
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.23
# global step 49400 learning rate 0.4008 step-time 0.62 perplexity 1.20
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.29
#   eval: bucket 3 perplexity 1.26
# global step 49600 learning rate 0.4008 step-time 0.61 perplexity 1.20
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.31
# global step 49800 learning rate 0.4008 step-time 0.61 perplexity 1.20
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 1.28
# global step 50000 learning rate 0.4008 step-time 0.60 perplexity 1.20
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.29
# global step 50200 learning rate 0.4008 step-time 0.62 perplexity 1.20
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.23
# global step 50400 learning rate 0.3968 step-time 0.63 perplexity 1.20
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.22
# global step 50600 learning rate 0.3968 step-time 0.60 perplexity 1.20
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 1.27
# global step 50800 learning rate 0.3968 step-time 0.59 perplexity 1.19
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 1.24
# global step 51000 learning rate 0.3968 step-time 0.58 perplexity 1.19
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.29
# global step 51200 learning rate 0.3968 step-time 0.63 perplexity 1.19
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-93fd337a0d5c> in <module>()
# ----> 1 train()
#
# <ipython-input-6-71b101afd3cb> in train()
#      31                       train_set, bucket_id)
#      32             _, step_loss, _ = model.step(sess, encoder_inputs, decoder_inputs,
# ---> 33                                                target_weights, bucket_id, False)
#      34             step_time += (time.time() - start_time) / FLAGS.steps_per_checkpoint
#      35             loss += step_loss / FLAGS.steps_per_checkpoint
#
# /home/sshschem/.local/lib/python2.7/site-packages/tensorflow/models/rnn/translate/seq2seq_model.pyc in step(self, session, encoder_inputs, decoder_inputs, target_weights, bucket_id, forward_only)
#     220         output_feed.append(self.outputs[bucket_id][l])
#     221
# --> 222     outputs = session.run(output_feed, input_feed)
#     223     if not forward_only:
#     224       return outputs[1], outputs[2], None  # Gradient norm, loss, no outputs.
#
# /home/sshschem/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     708     try:
#     709       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 710                          run_metadata_ptr)
#     711       if run_metadata:
#     712         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/sshschem/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     906     if final_fetches or final_targets:
#     907       results = self._do_run(handle, final_targets, final_fetches,
# --> 908                              feed_dict_string, options, run_metadata)
#     909     else:
#     910       results = []
#
# /home/sshschem/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     956     if handle is None:
#     957       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 958                            target_list, options, run_metadata)
#     959     else:
#     960       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/sshschem/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     963   def _do_call(self, fn, *args):
#     964     try:
# --> 965       return fn(*args)
#     966     except errors.OpError as e:
#     967       message = compat.as_text(e.message)
#
# /home/sshschem/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     945         return tf_session.TF_Run(session, options,
#     946                                  feed_dict, fetch_list, target_list,
# --> 947                                  status, run_metadata)
#     948
#     949     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
