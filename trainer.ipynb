# %%
from __future__ import absolute_import, division, print_function

import math, os, random, sys, time
import cPickle, gzip
import progressbar

import numpy as np
from six.moves import xrange
import tensorflow as tf

from tensorflow.models.rnn.translate import data_utils
from tensorflow.models.rnn.translate import seq2seq_model

# %%
tf.app.flags.DEFINE_float("learning_rate", 0.5, "Learning rate.")
tf.app.flags.DEFINE_float("learning_rate_decay_factor", 0.99,
                          "Learning rate decays by this much.")
tf.app.flags.DEFINE_float("max_gradient_norm", 5.0,
                          "Clip gradients to this norm.")
tf.app.flags.DEFINE_integer("batch_size", 64,
                            "Batch size to use during training.")
tf.app.flags.DEFINE_integer("size", 600, "Size of each model layer.")
tf.app.flags.DEFINE_integer("num_layers", 3, "Number of layers in the model.")
tf.app.flags.DEFINE_integer("reactant_vocab_size", 326, "Reactant vocabulary size.")
tf.app.flags.DEFINE_integer("product_vocab_size", 197, "Product vocabulary size.")
tf.app.flags.DEFINE_string("train_dir", "/home/sshschem/Documents/2016_thesis/checkpoint", "Training directory.")
tf.app.flags.DEFINE_integer("max_train_data_size", 0,
                            "Limit on the size of training data (0: no limit).")
tf.app.flags.DEFINE_integer("steps_per_checkpoint", 200,
                            "How many training steps to do per checkpoint.")
tf.app.flags.DEFINE_boolean("decode", False,
                            "Set to True for interactive decoding.")
tf.app.flags.DEFINE_boolean("self_test", False,
                            "Run a self-test if this is set to True.")

FLAGS = tf.app.flags.FLAGS

# %%
_buckets = [(54, 54), (70, 60), (90, 65), (150, 80)]

# %%
dev_set = [[] for _ in _buckets]
train_set = [[] for _ in _buckets]

bar_dev = progressbar.ProgressBar(max_value=10942)
bar_train = progressbar.ProgressBar(max_value=1083292)

with gzip.open('data/dev.pkl.gz', 'rb') as dev_file:
    i = 1
    while 1:
        try:
            reactants, products = cPickle.load(dev_file)
            products.append(data_utils.EOS_ID)
            for bucket_id, (source_size, target_size) in enumerate(_buckets):
                if len(reactants) < source_size and len(products) < target_size:
                    dev_set[bucket_id].append([reactants, products])
                    break
        except EOFError:
            break
        bar_dev.update(i)
        i += 1

with gzip.open('data/train.pkl.gz', 'rb') as train_file:
    i = 1
    while 1:
        try:
            reactants, products = cPickle.load(train_file)
            products.append(data_utils.EOS_ID)
            for bucket_id, (source_size, target_size) in enumerate(_buckets):
                if len(reactants) < source_size and len(products) < target_size:
                    train_set[bucket_id].append([reactants, products])
                    break
        except EOFError:
            break
        bar_train.update(i)
        i += 1
        
print("dev_set size:", [len(d) for d in dev_set])
print("train_set size:", [len(t) for t in train_set])
# Out:
#  99% (1081775 of 1083292) |################ | Elapsed Time: 0:02:31 ETA: 0:00:00
# dev_set size: [3793, 2772, 2307, 2056]
# train_set size: [373867, 278092, 228864, 201503]
# 100% (1083292 of 1083292) |################| Elapsed Time: 0:02:31 ETA:  0:00:00

# %%
def create_model(session, forward_only):
    model = seq2seq_model.Seq2SeqModel(
        FLAGS.reactant_vocab_size, FLAGS.product_vocab_size, _buckets,
        FLAGS.size, FLAGS.num_layers, FLAGS.max_gradient_norm, FLAGS.batch_size,
        FLAGS.learning_rate, FLAGS.learning_rate_decay_factor,
        forward_only=forward_only)
    ckpt = tf.train.get_checkpoint_state(FLAGS.train_dir)
    if ckpt and tf.gfile.Exists(ckpt.model_checkpoint_path):
        print("Reading model parameters from %s" % ckpt.model_checkpoint_path)
        model.saver.restore(session, ckpt.model_checkpoint_path)
    else:
        print("Created model with fresh parameters.")
        session.run(tf.initialize_all_variables())
    return model

# %%
def train():
    with tf.Session() as sess:
        # Create model.
        print("Creating %d layers of %d units." % (FLAGS.num_layers, FLAGS.size))
        model = create_model(sess, False)

        # Compute bucket sizes.      
        train_bucket_sizes = [len(train_set[b]) for b in xrange(len(_buckets))]
        train_total_size = float(sum(train_bucket_sizes))

        # A bucket scale is a list of increasing numbers from 0 to 1 that we'll use
        # to select a bucket. Length of [scale[i], scale[i+1]] is proportional to
        # the size if i-th training bucket, as used later.
        train_buckets_scale = [sum(train_bucket_sizes[:i + 1]) / train_total_size
                                for i in xrange(len(train_bucket_sizes))]

        # This is the training loop.
        step_time, loss = 0.0, 0.0
        current_step = 0
        previous_losses = []
        while True:
            # Choose a bucket according to data distribution. We pick a random number
            # in [0, 1] and use the corresponding interval in train_buckets_scale.
            random_number_01 = np.random.random_sample()
            bucket_id = min([i for i in xrange(len(train_buckets_scale))
            if train_buckets_scale[i] > random_number_01])

            # Get a batch and make a step.
            start_time = time.time()
            encoder_inputs, decoder_inputs, target_weights = model.get_batch(
                      train_set, bucket_id)
            _, step_loss, _ = model.step(sess, encoder_inputs, decoder_inputs,
                                               target_weights, bucket_id, False)
            step_time += (time.time() - start_time) / FLAGS.steps_per_checkpoint
            loss += step_loss / FLAGS.steps_per_checkpoint
            current_step += 1

            # Once in a while, we save checkpoint, print statistics, and run evals.
            if current_step % FLAGS.steps_per_checkpoint == 0:
                 # Print statistics for the previous epoch.
                perplexity = math.exp(loss) if loss < 300 else float('inf')
                print ("global step %d learning rate %.4f step-time %.2f perplexity "
                        "%.2f" % (model.global_step.eval(), model.learning_rate.eval(),
                                    step_time, perplexity))
                # Decrease learning rate if no improvement was seen over last 3 times.
                if len(previous_losses) > 2 and loss > max(previous_losses[-3:]):
                    sess.run(model.learning_rate_decay_op)
                previous_losses.append(loss)
                # Save checkpoint and zero timer and loss.
                checkpoint_path = os.path.join(FLAGS.train_dir, "translate.ckpt")
                model.saver.save(sess, checkpoint_path, global_step=model.global_step)
                step_time, loss = 0.0, 0.0
                # Run evals on development set and print their perplexity.
                for bucket_id in xrange(len(_buckets)):
                    if len(dev_set[bucket_id]) == 0:
                        print("  eval: empty bucket %d" % (bucket_id))
                        continue
                    encoder_inputs, decoder_inputs, target_weights = model.get_batch(
                        dev_set, bucket_id)
                    _, eval_loss, _ = model.step(sess, encoder_inputs, decoder_inputs,
                                                    target_weights, bucket_id, True)
                    eval_ppx = math.exp(eval_loss) if eval_loss < 300 else float('inf')
                    print("  eval: bucket %d perplexity %.2f" % (bucket_id, eval_ppx))

# %%
train()
# Out:
# Creating 3 layers of 600 units.
# Reading model parameters from /home/sshschem/Documents/2016_thesis/checkpoint/translate.ckpt-51200
# global step 51400 learning rate 0.3968 step-time 0.63 perplexity 1.20
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.24
# global step 51600 learning rate 0.3968 step-time 0.54 perplexity 1.19
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.25
# global step 51800 learning rate 0.3968 step-time 0.55 perplexity 1.19
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.24
# global step 52000 learning rate 0.3968 step-time 0.56 perplexity 1.19
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.29
# global step 52200 learning rate 0.3968 step-time 0.52 perplexity 1.19
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.24
# global step 52400 learning rate 0.3968 step-time 0.54 perplexity 1.19
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.26
# global step 52600 learning rate 0.3968 step-time 0.55 perplexity 1.19
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.37
# global step 52800 learning rate 0.3968 step-time 0.57 perplexity 1.19
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.27
# global step 53000 learning rate 0.3968 step-time 0.54 perplexity 1.19
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.26
# global step 53200 learning rate 0.3968 step-time 0.54 perplexity 1.19
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.24
# global step 53400 learning rate 0.3968 step-time 0.56 perplexity 1.19
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.33
# global step 53600 learning rate 0.3968 step-time 0.56 perplexity 1.19
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.27
# global step 53800 learning rate 0.3928 step-time 0.54 perplexity 1.19
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.23
# global step 54000 learning rate 0.3928 step-time 0.55 perplexity 1.19
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.23
# global step 54200 learning rate 0.3928 step-time 0.54 perplexity 1.18
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.29
# global step 54400 learning rate 0.3928 step-time 0.56 perplexity 1.19
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.30
# global step 54600 learning rate 0.3928 step-time 0.53 perplexity 1.19
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.26
# global step 54800 learning rate 0.3928 step-time 0.54 perplexity 1.19
#   eval: bucket 0 perplexity 1.23
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.27
# global step 55000 learning rate 0.3889 step-time 0.56 perplexity 1.19
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.20
# global step 55200 learning rate 0.3889 step-time 0.55 perplexity 1.19
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.28
# global step 55400 learning rate 0.3850 step-time 0.54 perplexity 1.18
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.27
# global step 55600 learning rate 0.3850 step-time 0.55 perplexity 1.18
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.23
# global step 55800 learning rate 0.3850 step-time 0.54 perplexity 1.18
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.22
# global step 56000 learning rate 0.3850 step-time 0.54 perplexity 1.19
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.32
# global step 56200 learning rate 0.3812 step-time 0.55 perplexity 1.18
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.26
# global step 56400 learning rate 0.3812 step-time 0.57 perplexity 1.18
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.26
# global step 56600 learning rate 0.3812 step-time 0.56 perplexity 1.18
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.28
# global step 56800 learning rate 0.3812 step-time 0.56 perplexity 1.18
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.26
# global step 57000 learning rate 0.3812 step-time 0.58 perplexity 1.19
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.30
# global step 57200 learning rate 0.3774 step-time 0.54 perplexity 1.18
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.27
# global step 57400 learning rate 0.3774 step-time 0.54 perplexity 1.18
#   eval: bucket 0 perplexity 1.23
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.24
# global step 57600 learning rate 0.3774 step-time 0.56 perplexity 1.18
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.22
# global step 57800 learning rate 0.3774 step-time 0.55 perplexity 1.18
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.21
# global step 58000 learning rate 0.3774 step-time 0.57 perplexity 1.18
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.29
# global step 58200 learning rate 0.3774 step-time 0.56 perplexity 1.18
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.19
# global step 58400 learning rate 0.3774 step-time 0.54 perplexity 1.17
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.18
# global step 58600 learning rate 0.3774 step-time 0.55 perplexity 1.18
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.23
# global step 58800 learning rate 0.3774 step-time 0.56 perplexity 1.18
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.28
# global step 59000 learning rate 0.3736 step-time 0.57 perplexity 1.18
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.23
# global step 59200 learning rate 0.3736 step-time 0.54 perplexity 1.17
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.24
# global step 59400 learning rate 0.3736 step-time 0.54 perplexity 1.18
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.20
# global step 59600 learning rate 0.3736 step-time 0.54 perplexity 1.18
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.29
# global step 59800 learning rate 0.3699 step-time 0.53 perplexity 1.18
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.23
# global step 60000 learning rate 0.3699 step-time 0.58 perplexity 1.18
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.18
# global step 60200 learning rate 0.3662 step-time 0.56 perplexity 1.17
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.35
# global step 60400 learning rate 0.3662 step-time 0.58 perplexity 1.18
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.22
# global step 60600 learning rate 0.3662 step-time 0.54 perplexity 1.17
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.21
# global step 60800 learning rate 0.3662 step-time 0.53 perplexity 1.17
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.30
# global step 61000 learning rate 0.3662 step-time 0.58 perplexity 1.18
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.23
# global step 61200 learning rate 0.3662 step-time 0.56 perplexity 1.17
#   eval: bucket 0 perplexity 1.22
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.27
# global step 61400 learning rate 0.3662 step-time 0.55 perplexity 1.17
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.18
# global step 61600 learning rate 0.3662 step-time 0.55 perplexity 1.17
#   eval: bucket 0 perplexity 1.22
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.23
# global step 61800 learning rate 0.3662 step-time 0.56 perplexity 1.17
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.21
# global step 62000 learning rate 0.3662 step-time 0.56 perplexity 1.17
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.21
# global step 62200 learning rate 0.3662 step-time 0.56 perplexity 1.17
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.23
# global step 62400 learning rate 0.3662 step-time 0.54 perplexity 1.17
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.23
# global step 62600 learning rate 0.3662 step-time 0.54 perplexity 1.17
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.22
# global step 62800 learning rate 0.3662 step-time 0.54 perplexity 1.17
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.31
# global step 63000 learning rate 0.3662 step-time 0.54 perplexity 1.17
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.22
# global step 63200 learning rate 0.3625 step-time 0.54 perplexity 1.17
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.19
# global step 63400 learning rate 0.3625 step-time 0.57 perplexity 1.17
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.23
# global step 63600 learning rate 0.3589 step-time 0.54 perplexity 1.17
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.26
# global step 63800 learning rate 0.3589 step-time 0.57 perplexity 1.17
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.23
# global step 64000 learning rate 0.3589 step-time 0.56 perplexity 1.17
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.19
# global step 64200 learning rate 0.3589 step-time 0.56 perplexity 1.17
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.24
# global step 64400 learning rate 0.3589 step-time 0.52 perplexity 1.17
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.21
# global step 64600 learning rate 0.3589 step-time 0.54 perplexity 1.16
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.25
# global step 64800 learning rate 0.3589 step-time 0.54 perplexity 1.17
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.23
# global step 65000 learning rate 0.3589 step-time 0.56 perplexity 1.17
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.27
# global step 65200 learning rate 0.3553 step-time 0.54 perplexity 1.17
#   eval: bucket 0 perplexity 1.23
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.27
# global step 65400 learning rate 0.3553 step-time 0.55 perplexity 1.17
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.27
# global step 65600 learning rate 0.3553 step-time 0.55 perplexity 1.16
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.29
# global step 65800 learning rate 0.3553 step-time 0.55 perplexity 1.16
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.24
# global step 66000 learning rate 0.3553 step-time 0.55 perplexity 1.17
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.24
# global step 66200 learning rate 0.3553 step-time 0.58 perplexity 1.16
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.23
# global step 66400 learning rate 0.3553 step-time 0.58 perplexity 1.17
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.21
# global step 66600 learning rate 0.3517 step-time 0.56 perplexity 1.16
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.16
# global step 66800 learning rate 0.3517 step-time 0.53 perplexity 1.16
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.29
# global step 67000 learning rate 0.3517 step-time 0.56 perplexity 1.16
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.22
# global step 67200 learning rate 0.3517 step-time 0.53 perplexity 1.16
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.19
# global step 67400 learning rate 0.3517 step-time 0.55 perplexity 1.16
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.26
# global step 67600 learning rate 0.3517 step-time 0.56 perplexity 1.17
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.19
# global step 67800 learning rate 0.3482 step-time 0.54 perplexity 1.16
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.24
# global step 68000 learning rate 0.3482 step-time 0.55 perplexity 1.16
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.26
# global step 68200 learning rate 0.3482 step-time 0.54 perplexity 1.16
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.22
# global step 68400 learning rate 0.3482 step-time 0.56 perplexity 1.16
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.21
# global step 68600 learning rate 0.3482 step-time 0.55 perplexity 1.16
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.22
# global step 68800 learning rate 0.3482 step-time 0.56 perplexity 1.16
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.25
# global step 69000 learning rate 0.3447 step-time 0.54 perplexity 1.16
#   eval: bucket 0 perplexity 1.23
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.22
# global step 69200 learning rate 0.3447 step-time 0.54 perplexity 1.16
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.21
# global step 69400 learning rate 0.3447 step-time 0.56 perplexity 1.16
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.19
# global step 69600 learning rate 0.3447 step-time 0.54 perplexity 1.16
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.23
# global step 69800 learning rate 0.3413 step-time 0.56 perplexity 1.16
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.21
# global step 70000 learning rate 0.3413 step-time 0.55 perplexity 1.16
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.21
# global step 70200 learning rate 0.3413 step-time 0.55 perplexity 1.16
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.26
# global step 70400 learning rate 0.3413 step-time 0.55 perplexity 1.16
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.24
# global step 70600 learning rate 0.3413 step-time 0.54 perplexity 1.16
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.25
# global step 70800 learning rate 0.3413 step-time 0.54 perplexity 1.15
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.18
# global step 71000 learning rate 0.3413 step-time 0.56 perplexity 1.16
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.22
# global step 71200 learning rate 0.3379 step-time 0.55 perplexity 1.16
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.22
# global step 71400 learning rate 0.3379 step-time 0.53 perplexity 1.15
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.22
# global step 71600 learning rate 0.3379 step-time 0.56 perplexity 1.16
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.28
# global step 71800 learning rate 0.3345 step-time 0.53 perplexity 1.15
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.22
# global step 72000 learning rate 0.3345 step-time 0.55 perplexity 1.15
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.19
# global step 72200 learning rate 0.3345 step-time 0.52 perplexity 1.15
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.22
# global step 72400 learning rate 0.3345 step-time 0.58 perplexity 1.15
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.20
# global step 72600 learning rate 0.3311 step-time 0.55 perplexity 1.15
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.19
# global step 72800 learning rate 0.3311 step-time 0.57 perplexity 1.15
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.22
# global step 73000 learning rate 0.3311 step-time 0.57 perplexity 1.15
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.21
# global step 73200 learning rate 0.3278 step-time 0.55 perplexity 1.15
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.23
# global step 73400 learning rate 0.3278 step-time 0.55 perplexity 1.15
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.22
# global step 73600 learning rate 0.3278 step-time 0.54 perplexity 1.15
#   eval: bucket 0 perplexity 1.22
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.25
# global step 73800 learning rate 0.3278 step-time 0.55 perplexity 1.15
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.20
# global step 74000 learning rate 0.3278 step-time 0.56 perplexity 1.15
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.21
# global step 74200 learning rate 0.3278 step-time 0.56 perplexity 1.15
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.23
# global step 74400 learning rate 0.3278 step-time 0.56 perplexity 1.15
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.23
# global step 74600 learning rate 0.3278 step-time 0.56 perplexity 1.15
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.25
# global step 74800 learning rate 0.3278 step-time 0.57 perplexity 1.15
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.21
# global step 75000 learning rate 0.3278 step-time 0.55 perplexity 1.15
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.23
# global step 75200 learning rate 0.3278 step-time 0.56 perplexity 1.15
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.16
# global step 75400 learning rate 0.3278 step-time 0.56 perplexity 1.15
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.15
# global step 75600 learning rate 0.3278 step-time 0.55 perplexity 1.15
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.19
# global step 75800 learning rate 0.3246 step-time 0.54 perplexity 1.15
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.21
# global step 76000 learning rate 0.3246 step-time 0.55 perplexity 1.14
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.27
# global step 76200 learning rate 0.3246 step-time 0.56 perplexity 1.15
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.19
# global step 76400 learning rate 0.3246 step-time 0.56 perplexity 1.15
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.24
# global step 76600 learning rate 0.3246 step-time 0.56 perplexity 1.15
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.20
# global step 76800 learning rate 0.3246 step-time 0.54 perplexity 1.14
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.22
# global step 77000 learning rate 0.3246 step-time 0.56 perplexity 1.15
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.25
# global step 77200 learning rate 0.3246 step-time 0.55 perplexity 1.15
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.21
# global step 77400 learning rate 0.3246 step-time 0.55 perplexity 1.15
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.23
# global step 77600 learning rate 0.3246 step-time 0.55 perplexity 1.14
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.17
# global step 77800 learning rate 0.3246 step-time 0.55 perplexity 1.15
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.23
# global step 78000 learning rate 0.3213 step-time 0.53 perplexity 1.14
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.16
# global step 78200 learning rate 0.3213 step-time 0.54 perplexity 1.14
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.20
# global step 78400 learning rate 0.3213 step-time 0.55 perplexity 1.15
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.20
# global step 78600 learning rate 0.3213 step-time 0.55 perplexity 1.15
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.17
# global step 78800 learning rate 0.3213 step-time 0.54 perplexity 1.15
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.20
# global step 79000 learning rate 0.3213 step-time 0.54 perplexity 1.14
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.16
# global step 79200 learning rate 0.3213 step-time 0.56 perplexity 1.15
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.24
# global step 79400 learning rate 0.3181 step-time 0.55 perplexity 1.14
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.26
# global step 79600 learning rate 0.3181 step-time 0.53 perplexity 1.14
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.21
# global step 79800 learning rate 0.3181 step-time 0.54 perplexity 1.14
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.22
# global step 80000 learning rate 0.3181 step-time 0.55 perplexity 1.14
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.22
# global step 80200 learning rate 0.3181 step-time 0.54 perplexity 1.14
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.20
# global step 80400 learning rate 0.3149 step-time 0.56 perplexity 1.14
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.22
# global step 80600 learning rate 0.3149 step-time 0.54 perplexity 1.14
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.22
# global step 80800 learning rate 0.3149 step-time 0.56 perplexity 1.14
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.17
# global step 81000 learning rate 0.3149 step-time 0.55 perplexity 1.15
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.16
# global step 81200 learning rate 0.3118 step-time 0.52 perplexity 1.14
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.20
# global step 81400 learning rate 0.3118 step-time 0.56 perplexity 1.14
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.23
# global step 81600 learning rate 0.3118 step-time 0.56 perplexity 1.14
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.19
# global step 81800 learning rate 0.3118 step-time 0.57 perplexity 1.14
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.22
# global step 82000 learning rate 0.3086 step-time 0.55 perplexity 1.14
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.21
# global step 82200 learning rate 0.3086 step-time 0.55 perplexity 1.14
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.27
# global step 82400 learning rate 0.3086 step-time 0.55 perplexity 1.14
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.23
# global step 82600 learning rate 0.3086 step-time 0.57 perplexity 1.14
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.19
# global step 82800 learning rate 0.3086 step-time 0.56 perplexity 1.14
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.20
# global step 83000 learning rate 0.3086 step-time 0.56 perplexity 1.14
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.26
# global step 83200 learning rate 0.3056 step-time 0.54 perplexity 1.13
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.28
# global step 83400 learning rate 0.3056 step-time 0.55 perplexity 1.14
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.19
# global step 83600 learning rate 0.3056 step-time 0.56 perplexity 1.14
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.26
# global step 83800 learning rate 0.3056 step-time 0.54 perplexity 1.14
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.20
# global step 84000 learning rate 0.3056 step-time 0.53 perplexity 1.14
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.16
# global step 84200 learning rate 0.3056 step-time 0.55 perplexity 1.14
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.22
# global step 84400 learning rate 0.3056 step-time 0.55 perplexity 1.13
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.20
# global step 84600 learning rate 0.3056 step-time 0.56 perplexity 1.14
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.17
# global step 84800 learning rate 0.3025 step-time 0.55 perplexity 1.14
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.21
# global step 85000 learning rate 0.3025 step-time 0.55 perplexity 1.14
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.19
# global step 85200 learning rate 0.3025 step-time 0.55 perplexity 1.14
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.20
# global step 85400 learning rate 0.3025 step-time 0.57 perplexity 1.14
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.22
# global step 85600 learning rate 0.2995 step-time 0.54 perplexity 1.14
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.17
# global step 85800 learning rate 0.2995 step-time 0.54 perplexity 1.13
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.22
# global step 86000 learning rate 0.2995 step-time 0.57 perplexity 1.14
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.15
# global step 86200 learning rate 0.2995 step-time 0.52 perplexity 1.13
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.19
# global step 86400 learning rate 0.2995 step-time 0.53 perplexity 1.13
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.17
# global step 86600 learning rate 0.2995 step-time 0.54 perplexity 1.13
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.15
# global step 86800 learning rate 0.2995 step-time 0.55 perplexity 1.13
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.22
# global step 87000 learning rate 0.2995 step-time 0.55 perplexity 1.13
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.19
# global step 87200 learning rate 0.2965 step-time 0.55 perplexity 1.13
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.17
# global step 87400 learning rate 0.2965 step-time 0.55 perplexity 1.13
#   eval: bucket 0 perplexity 1.22
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.18
# global step 87600 learning rate 0.2935 step-time 0.55 perplexity 1.13
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.18
# global step 87800 learning rate 0.2935 step-time 0.57 perplexity 1.13
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.25
# global step 88000 learning rate 0.2906 step-time 0.54 perplexity 1.13
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.21
# global step 88200 learning rate 0.2906 step-time 0.53 perplexity 1.13
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.18
# global step 88400 learning rate 0.2906 step-time 0.55 perplexity 1.13
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.21
# global step 88600 learning rate 0.2906 step-time 0.57 perplexity 1.14
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.20
# global step 88800 learning rate 0.2877 step-time 0.58 perplexity 1.14
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.16
# global step 89000 learning rate 0.2848 step-time 0.54 perplexity 1.13
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.19
# global step 89200 learning rate 0.2848 step-time 0.55 perplexity 1.13
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.22
# global step 89400 learning rate 0.2848 step-time 0.53 perplexity 1.13
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.18
# global step 89600 learning rate 0.2848 step-time 0.57 perplexity 1.13
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.24
# global step 89800 learning rate 0.2848 step-time 0.52 perplexity 1.13
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.19
# global step 90000 learning rate 0.2848 step-time 0.57 perplexity 1.13
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.23
# global step 90200 learning rate 0.2848 step-time 0.57 perplexity 1.13
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.15
# global step 90400 learning rate 0.2848 step-time 0.52 perplexity 1.13
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.20
# global step 90600 learning rate 0.2848 step-time 0.57 perplexity 1.13
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.19
# global step 90800 learning rate 0.2848 step-time 0.55 perplexity 1.13
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.15
# global step 91000 learning rate 0.2848 step-time 0.54 perplexity 1.13
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.16
# global step 91200 learning rate 0.2848 step-time 0.56 perplexity 1.13
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.21
# global step 91400 learning rate 0.2820 step-time 0.53 perplexity 1.13
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.21
# global step 91600 learning rate 0.2820 step-time 0.57 perplexity 1.13
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.21
# global step 91800 learning rate 0.2791 step-time 0.55 perplexity 1.13
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.21
# global step 92000 learning rate 0.2791 step-time 0.54 perplexity 1.12
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.16
# global step 92200 learning rate 0.2791 step-time 0.52 perplexity 1.13
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.24
# global step 92400 learning rate 0.2791 step-time 0.56 perplexity 1.13
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.23
# global step 92600 learning rate 0.2763 step-time 0.55 perplexity 1.13
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.18
# global step 92800 learning rate 0.2763 step-time 0.55 perplexity 1.12
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.21
# global step 93000 learning rate 0.2763 step-time 0.55 perplexity 1.13
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.20
# global step 93200 learning rate 0.2763 step-time 0.57 perplexity 1.13
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.18
# global step 93400 learning rate 0.2763 step-time 0.56 perplexity 1.13
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.23
# global step 93600 learning rate 0.2763 step-time 0.55 perplexity 1.13
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.21
# global step 93800 learning rate 0.2763 step-time 0.56 perplexity 1.13
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.20
# global step 94000 learning rate 0.2736 step-time 0.56 perplexity 1.13
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.16
# global step 94200 learning rate 0.2736 step-time 0.53 perplexity 1.12
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.17
# global step 94400 learning rate 0.2736 step-time 0.56 perplexity 1.13
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.21
# global step 94600 learning rate 0.2736 step-time 0.57 perplexity 1.13
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.24
# global step 94800 learning rate 0.2708 step-time 0.57 perplexity 1.13
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.19
# global step 95000 learning rate 0.2708 step-time 0.55 perplexity 1.12
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.25
# global step 95200 learning rate 0.2708 step-time 0.57 perplexity 1.13
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.18
# global step 95400 learning rate 0.2708 step-time 0.56 perplexity 1.13
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.22
# global step 95600 learning rate 0.2708 step-time 0.57 perplexity 1.12
#   eval: bucket 0 perplexity 1.23
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.23
# global step 95800 learning rate 0.2708 step-time 0.55 perplexity 1.12
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.26
# global step 96000 learning rate 0.2708 step-time 0.55 perplexity 1.12
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.21
# global step 96200 learning rate 0.2708 step-time 0.56 perplexity 1.13
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.16
# global step 96400 learning rate 0.2681 step-time 0.54 perplexity 1.12
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.22
# global step 96600 learning rate 0.2681 step-time 0.52 perplexity 1.12
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.22
# global step 96800 learning rate 0.2681 step-time 0.55 perplexity 1.12
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.16
# global step 97000 learning rate 0.2681 step-time 0.57 perplexity 1.13
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.16
# global step 97200 learning rate 0.2655 step-time 0.54 perplexity 1.12
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.18
# global step 97400 learning rate 0.2655 step-time 0.56 perplexity 1.13
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.22
# global step 97600 learning rate 0.2628 step-time 0.54 perplexity 1.12
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.20
# global step 97800 learning rate 0.2628 step-time 0.57 perplexity 1.12
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.16
# global step 98000 learning rate 0.2628 step-time 0.58 perplexity 1.12
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.21
# global step 98200 learning rate 0.2628 step-time 0.56 perplexity 1.12
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.12
# global step 98400 learning rate 0.2628 step-time 0.57 perplexity 1.12
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.18
# global step 98600 learning rate 0.2628 step-time 0.54 perplexity 1.12
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.16
# ...
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.17
# global step 147000 learning rate 0.1558 step-time 0.53 perplexity 1.09
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.16
# global step 147200 learning rate 0.1558 step-time 0.55 perplexity 1.08
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.17
# global step 147400 learning rate 0.1558 step-time 0.55 perplexity 1.09
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.16
# global step 147600 learning rate 0.1558 step-time 0.55 perplexity 1.09
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.10
#   eval: bucket 3 perplexity 1.22
# global step 147800 learning rate 0.1543 step-time 0.55 perplexity 1.09
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.15
# global step 148000 learning rate 0.1527 step-time 0.54 perplexity 1.09
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.20
# global step 148200 learning rate 0.1527 step-time 0.57 perplexity 1.09
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.15
# global step 148400 learning rate 0.1512 step-time 0.56 perplexity 1.08
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.13
# global step 148600 learning rate 0.1512 step-time 0.57 perplexity 1.09
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.15
# global step 148800 learning rate 0.1497 step-time 0.57 perplexity 1.09
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.18
# global step 149000 learning rate 0.1497 step-time 0.55 perplexity 1.09
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.11
# global step 149200 learning rate 0.1497 step-time 0.56 perplexity 1.08
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.09
#   eval: bucket 3 perplexity 1.15
# global step 149400 learning rate 0.1497 step-time 0.56 perplexity 1.09
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.16
# global step 149600 learning rate 0.1482 step-time 0.54 perplexity 1.09
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.12
#   eval: bucket 3 perplexity 1.17
# global step 149800 learning rate 0.1482 step-time 0.55 perplexity 1.09
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.19
# global step 150000 learning rate 0.1467 step-time 0.53 perplexity 1.09
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.12
# global step 150200 learning rate 0.1467 step-time 0.53 perplexity 1.08
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.14
# global step 150400 learning rate 0.1467 step-time 0.54 perplexity 1.09
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.18
# global step 150600 learning rate 0.1467 step-time 0.56 perplexity 1.09
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.11
#   eval: bucket 3 perplexity 1.18
# global step 150800 learning rate 0.1467 step-time 0.56 perplexity 1.08
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.12
#   eval: bucket 3 perplexity 1.21
# global step 151000 learning rate 0.1467 step-time 0.56 perplexity 1.09
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.15
# global step 151200 learning rate 0.1467 step-time 0.54 perplexity 1.09
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.18
# global step 151400 learning rate 0.1467 step-time 0.54 perplexity 1.08
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.21
# global step 151600 learning rate 0.1467 step-time 0.55 perplexity 1.09
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.11
#   eval: bucket 3 perplexity 1.19
# global step 151800 learning rate 0.1452 step-time 0.55 perplexity 1.09
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.10
#   eval: bucket 3 perplexity 1.21
# global step 152000 learning rate 0.1452 step-time 0.55 perplexity 1.09
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.15
# global step 152200 learning rate 0.1438 step-time 0.55 perplexity 1.09
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.11
#   eval: bucket 3 perplexity 1.15
# global step 152400 learning rate 0.1424 step-time 0.56 perplexity 1.09
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.12
# global step 152600 learning rate 0.1424 step-time 0.53 perplexity 1.08
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.15
# global step 152800 learning rate 0.1424 step-time 0.54 perplexity 1.08
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.13
# global step 153000 learning rate 0.1424 step-time 0.52 perplexity 1.08
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.11
#   eval: bucket 3 perplexity 1.17
# global step 153200 learning rate 0.1424 step-time 0.56 perplexity 1.09
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.11
#   eval: bucket 3 perplexity 1.17
# global step 153400 learning rate 0.1409 step-time 0.53 perplexity 1.08
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.11
#   eval: bucket 3 perplexity 1.21
# global step 153600 learning rate 0.1409 step-time 0.55 perplexity 1.08
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.17
# global step 153800 learning rate 0.1409 step-time 0.53 perplexity 1.08
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.11
#   eval: bucket 3 perplexity 1.15
# global step 154000 learning rate 0.1409 step-time 0.54 perplexity 1.08
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.17
# global step 154200 learning rate 0.1409 step-time 0.55 perplexity 1.08
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.21
# global step 154400 learning rate 0.1409 step-time 0.54 perplexity 1.08
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.12
# global step 154600 learning rate 0.1409 step-time 0.54 perplexity 1.08
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.12
#   eval: bucket 3 perplexity 1.21
# global step 154800 learning rate 0.1395 step-time 0.55 perplexity 1.08
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.14
# global step 155000 learning rate 0.1395 step-time 0.56 perplexity 1.08
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.12
#   eval: bucket 3 perplexity 1.19
# global step 155200 learning rate 0.1395 step-time 0.53 perplexity 1.08
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.12
#   eval: bucket 3 perplexity 1.21
# global step 155400 learning rate 0.1395 step-time 0.56 perplexity 1.08
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.14
# global step 155600 learning rate 0.1395 step-time 0.55 perplexity 1.08
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.19
# global step 155800 learning rate 0.1381 step-time 0.54 perplexity 1.08
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.14
# global step 156000 learning rate 0.1381 step-time 0.55 perplexity 1.09
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.15
# global step 156200 learning rate 0.1367 step-time 0.52 perplexity 1.08
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.16
# global step 156400 learning rate 0.1367 step-time 0.57 perplexity 1.08
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.21
# global step 156600 learning rate 0.1367 step-time 0.56 perplexity 1.09
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.11
#   eval: bucket 3 perplexity 1.15
# global step 156800 learning rate 0.1367 step-time 0.55 perplexity 1.08
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.15
# global step 157000 learning rate 0.1367 step-time 0.54 perplexity 1.08
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.11
#   eval: bucket 3 perplexity 1.16
# global step 157200 learning rate 0.1367 step-time 0.54 perplexity 1.08
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.15
# global step 157400 learning rate 0.1367 step-time 0.57 perplexity 1.08
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.15
# global step 157600 learning rate 0.1354 step-time 0.56 perplexity 1.08
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.18
# global step 157800 learning rate 0.1340 step-time 0.56 perplexity 1.08
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.21
# global step 158000 learning rate 0.1340 step-time 0.56 perplexity 1.08
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.17
# global step 158200 learning rate 0.1327 step-time 0.57 perplexity 1.08
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.10
#   eval: bucket 3 perplexity 1.15
# global step 158400 learning rate 0.1327 step-time 0.54 perplexity 1.08
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.14
# global step 158600 learning rate 0.1327 step-time 0.56 perplexity 1.08
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.20
# global step 158800 learning rate 0.1327 step-time 0.57 perplexity 1.08
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.08
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.20
# global step 159000 learning rate 0.1327 step-time 0.54 perplexity 1.08
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.10
#   eval: bucket 3 perplexity 1.16
# global step 159200 learning rate 0.1327 step-time 0.54 perplexity 1.08
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.12
#   eval: bucket 3 perplexity 1.14
# global step 159400 learning rate 0.1327 step-time 0.55 perplexity 1.08
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-93fd337a0d5c> in <module>()
# ----> 1 train()
#
# <ipython-input-6-71b101afd3cb> in train()
#      31                       train_set, bucket_id)
#      32             _, step_loss, _ = model.step(sess, encoder_inputs, decoder_inputs,
# ---> 33                                                target_weights, bucket_id, False)
#      34             step_time += (time.time() - start_time) / FLAGS.steps_per_checkpoint
#      35             loss += step_loss / FLAGS.steps_per_checkpoint
#
# /home/sshschem/.local/lib/python2.7/site-packages/tensorflow/models/rnn/translate/seq2seq_model.pyc in step(self, session, encoder_inputs, decoder_inputs, target_weights, bucket_id, forward_only)
#     220         output_feed.append(self.outputs[bucket_id][l])
#     221
# --> 222     outputs = session.run(output_feed, input_feed)
#     223     if not forward_only:
#     224       return outputs[1], outputs[2], None  # Gradient norm, loss, no outputs.
#
# /home/sshschem/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     708     try:
#     709       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 710                          run_metadata_ptr)
#     711       if run_metadata:
#     712         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/sshschem/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     906     if final_fetches or final_targets:
#     907       results = self._do_run(handle, final_targets, final_fetches,
# --> 908                              feed_dict_string, options, run_metadata)
#     909     else:
#     910       results = []
#
# /home/sshschem/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     956     if handle is None:
#     957       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 958                            target_list, options, run_metadata)
#     959     else:
#     960       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/sshschem/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     963   def _do_call(self, fn, *args):
#     964     try:
# --> 965       return fn(*args)
#     966     except errors.OpError as e:
#     967       message = compat.as_text(e.message)
#
# /home/sshschem/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     945         return tf_session.TF_Run(session, options,
#     946                                  feed_dict, fetch_list, target_list,
# --> 947                                  status, run_metadata)
#     948
#     949     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
