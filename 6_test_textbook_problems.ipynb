# %%
from __future__ import absolute_import, division, print_function

import cPickle, gzip, glob
from six.moves import xrange
import numpy as np
import tensorflow as tf

from tensorflow.models.rnn.translate import data_utils
import seq2seq_model

from rdkit import Chem
from rdkit.Chem import AllChem
import parser.Smipar as Smipar

from rdkit import DataStructs
from rdkit.Chem.Fingerprints import FingerprintMols

# %%
flags = tf.app.flags

flags.DEFINE_float("learning_rate", 0.5, "Learning rate.")
flags.DEFINE_float("learning_rate_decay_factor", 0.99, "Learning rate decays by this much.")
flags.DEFINE_float("max_gradient_norm", 5.0, "Clip gradients to this norm.")
flags.DEFINE_integer("batch_size", 1, "Batch size to use during training.")
flags.DEFINE_integer("size", 600, "Size of each model layer.")
flags.DEFINE_integer("num_layers", 3, "Number of layers in the model.")
flags.DEFINE_integer("reactant_vocab_size", 311, "Reactant vocabulary size.")
flags.DEFINE_integer("product_vocab_size", 180, "Product vocabulary size.")
flags.DEFINE_string("train_dir", "checkpoint/saved_models", "Training dir.")
FLAGS = flags.FLAGS

_buckets = [(54, 54), (70, 60), (90, 65), (150, 80)]

with gzip.open('data/vocab/vocab_list.pkl.gz', 'rb') as list_file:
    reactants_token_list, products_token_list = cPickle.load(list_file)

# %%
def create_model(session, forward_only):
    model = seq2seq_model.Seq2SeqModel( \
        FLAGS.reactant_vocab_size, FLAGS.product_vocab_size, _buckets, \
        FLAGS.size, FLAGS.num_layers, FLAGS.max_gradient_norm, FLAGS.batch_size, \
        FLAGS.learning_rate, FLAGS.learning_rate_decay_factor, forward_only=forward_only)
    ckpt = tf.train.get_checkpoint_state(FLAGS.train_dir)
    if ckpt and tf.gfile.Exists(ckpt.model_checkpoint_path):
        print("Reading model parameters from %s" % ckpt.model_checkpoint_path)
        model.saver.restore(session, ckpt.model_checkpoint_path)
    else:
        print("Created model with fresh parameters.")
        session.run(tf.initialize_all_variables())
    return model

def cano(smiles): # canonicalize smiles by MolToSmiles function
    return Chem.MolToSmiles(Chem.MolFromSmiles(smiles)) if (smiles != '') else ''

def fp_sim(smiles1, smiles2): # fingerprint similarity (Tanimoto)
    try:
        fp1 = FingerprintMols.FingerprintMol(Chem.MolFromSmiles(smiles1))
        fp2 = FingerprintMols.FingerprintMol(Chem.MolFromSmiles(smiles2))
        return DataStructs.FingerprintSimilarity(fp1, fp2)
    except:
        return 0
    
def avg(l):
    return sum(l)/float(len(l))

# %%
loss_list = [[] for _ in range(10)]
sim_list = [[] for _ in range(10)]
products_list = [[] for _ in range(10)]

with tf.Session() as sess:
    model = create_model(sess, True)
    
    for i, rxn_file in enumerate(glob.iglob('data/problems/*.txt')):
        with open(rxn_file, 'r') as f:
            rsmi_list = f.read().splitlines()
        
        for rsmi in rsmi_list: # list of RSMIs to be tested

            reactant_list = []
            agent_list = []
            product_list = []

            split_rsmi = rsmi.split('>')
            reactants = cano(split_rsmi[0]).split('.')
            agents = cano(split_rsmi[1]).split('.')
            products = cano(split_rsmi[2]).split('.')

            for reactant in reactants:
                reactant_list += Smipar.parser_list(reactant)
                reactant_list += '.'
            for agent in agents:
                agent_list += Smipar.parser_list(agent)
                agent_list += '.'
            for product in products:
                product_list += Smipar.parser_list(product)
                product_list += '.'

            reactant_list.pop() # to pop last '.'
            agent_list.pop()
            product_list.pop()

            products.append(data_utils.EOS_ID)

            reactant_list += '>'
            reactant_list += agent_list

            token_ids = [reactants_token_list.index(r) for r in reactant_list]
            product_ids = [products_token_list.index(p) for p in product_list]

            bucket_id = min([b for b in xrange(len(_buckets)) if _buckets[b][0] > len(token_ids)])
            encoder_inputs, decoder_inputs, target_weights = model.get_batch( \
                                       {bucket_id: [(token_ids, product_ids)]}, bucket_id)
            _, loss, output_logits = model.step(sess, encoder_inputs, decoder_inputs,
                                           target_weights, bucket_id, True)

            outputs = [int(np.argmax(logit, axis=1)) for logit in output_logits]
            if data_utils.EOS_ID in outputs:
                outputs = outputs[:outputs.index(data_utils.EOS_ID)]
            products_ = ''.join([tf.compat.as_str(products_token_list[output]) for output in outputs])

            loss_list[i].append(loss)
            sim_list[i].append(fp_sim(split_rsmi[2], products_))
            products_list[i].append(products_)
            
            print(rsmi, products_list[i][-1], sim_list[i][-1])
            
        print(rxn_file, avg(loss_list[i]), avg(sim_list[i]), sim_list[i].count(1), sim_list[i].count(0), sep='\t')
        print('-' * 15)
        
    for i, rxn_file in enumerate(glob.iglob('data/problems/*.txt')):
        print(rxn_file, avg(loss_list[i]), avg(sim_list[i]), sim_list[i].count(1), sim_list[i].count(0), sep='\t')
# Out:
# Reading model parameters from checkpoint/saved_models/gen.ckpt-8
# CC=C(C)C.Cl>>CCC(C)(C)Cl CCC(C)(C)Cl 1.0
# CC1=CCCC1.BrBr>ClC(Cl)(Cl)Cl>CC1(Br)CCCC1Br CC1(Br)CCCC1Br 1.0
# CC1=CCCC1.O>[H]B([H])[H].C1CCOC1.OO.[Na+].[OH-]>CC1CCCC1O CC1CCCC1O 1.0
# CCC(C)=CC.[O-][O+]=O>CSC>CC=O.CCC(C)=O CC=O.CCC(C)=O 1.0
# CC=C1CCCCC1.Br>COOC>CC(Br)C1CCCCC1 CC(Br)C1CCCCC1 1.0
# CC=C1CCCCC1.Cl>COOC>CCC1(Cl)CCCCC1 CCC1(O)CCCCC1 0.4625
# CCC=CC>OOC(=O)c1ccccc1>CCC1OC1C CCC1OC1C 1.0
# CC1=CCCC1>O=[Os](=O)(=O)=O.OO>CC1(O)CCCC1O CC1(O)CCCC1O 1.0
# CC1=CCCCC1>[K+].[O-][Mn](=O)(=O)=O.[OH-]>CC1(O)CCCCC1O CC1(O)CCCCC1O 1.0
# CC1=CCCCC1>CC(=O)OO.OS(O)(=O)=O>CC(=O)CCCCC(O)=O CC1=C(C2CCCC)OCC1 0
# CC1=CCCCC1.[O-][O+]=O>CSC>CC(=O)CCCCC=O CC(=O)CCCCC=O 1.0
# CC1=C(C)CCCC1.[H][H]>[Pt]>CC1CCCCC1C CC1CCCCC1C 1.0
# C1CCC2=CCCCC2C1.O>OS(O)(=O)=O>OC12CCCCC1CCCC2 OC12CCCCC1CCCC2 1.0
# C1CCC2=CCCCC2C1.O>CC(=O)O[Hg]OC(C)=O.[Na+].[H][B-]([H])([H])[H]>OC12CCCCC1CCCC2 OC12CCCCC1CCCC2 1.0
# C1CCC2=CCCCC2C1.ClCl.O>>OC12CCCCC1CCCC2Cl OC12CCCCC1CCCC2Cl 1.0
# data/problems/8-47.txt	1.07091126624	0.8975	13	1
# ---------------
# CCC(C)(Br)Br>[Na+].[NH2-]>CCC#C CCC(C)(C)Br 0.285714285714
# CCC(C)(Br)Br>[K+].[OH-]>CC#CC CCC(C)Br 0.294117647059
# CCC#C.CCCCBr>[Na+].[NH2-]>CCCCC#CCC CCCC=CC(C)C 0.4
# C1CCCCC#CCCC1.[H][H]>c1ccc2ncccc2c1.[Pd].[Ba++].[O-]S([O-])(=O)=O>C1CCCCC=CCCC1 C1=CCCCCCCCC1 1.0
# C1CCCCC#CCCC1>N.[Na]>C1CCCCC=CCCC1 C1=CCCCCCCCC1 1.0
# CCCCC#C>CC(C)C(C)BC(C)C(C)C.OO.[Na+].[OH-]>CCCCCC=O CCCCCC(C)C=O 0.636363636364
# CCCC#C.[H][H]>c1ccc2ncccc2c1.[Pd].[Ba++].[O-]S([O-])(=O)=O>CCCC=C C=CCCC 1.0
# data/problems/9-34.txt	8.38281387964	0.659456509877	3	0
# ---------------
# c1ccccc1.CC(C)(C)Br>[Al+3].[Cl-].[Cl-].[Cl-]>CC(C)(C)c1ccccc1 CC(C)(C)c1ccccc1 1.0
# c1ccccc1.CCCCCl>[Al+3].[Cl-].[Cl-].[Cl-]>CCC(C)c1ccccc1 CCCCc1ccccc1 0.735294117647
# c1ccccc1.CC(C)CO>FB(F)F>CC(C)(C)c1ccccc1 CC(C)COc1ccccc1 0.31884057971
# c1ccccc1.BrBr>[Fe]>Brc1ccccc1 Brc1ccccc1 1.0
# c1ccccc1.CC(C)=C>F>CC(C)(C)c1ccccc1 CC(C)(C)c1ccccc1C 0.743362831858
# c1ccccc1.O=S(=O)=O>OS(O)(=O)=O>OS(=O)(=O)c1ccccc1 O=C(Cl)c1ccccc1 0.276315789474
# c1ccccc1.CC(C)(C)CCl>[Al+3].[Cl-].[Cl-].[Cl-]>CCC(C)(C)c1ccccc1 CC(C)(C)Cc1ccccc1 0.666666666667
# c1ccccc1.ClC(=O)c1ccccc1>[Al+3].[Cl-].[Cl-].[Cl-]>O=C(c1ccccc1)c1ccccc1 OCc1ccccc1 0.505617977528
# c1ccccc1.II>O[N+]([O-])=O>Ic1ccccc1 Oc1ccccc1 0.512820512821
# c1ccccc1.O[N+]([O-])=O>OS(O)(=O)=O>[O-][N+](=O)c1ccccc1 O=C(O)c1ccccc1 0.272727272727
# c1ccccc1.[C-]#[O+]>[Al+3].[Cu+].[Cl-].[Cl-].[Cl-].Cl.[Cl-]>O=Cc1ccccc1 BrC1 0
# data/problems/17-44.txt	10.7509029969	0.548331431676	2	1
# ---------------
# CCC(C)O.Cc1ccc(cc1)S(Cl)(=O)=O>c1ccncc1>CCC(C)OS(=O)(=O)c1ccc(C)cc1 CCC(C)OS(=O)(=O)c1ccc(C)cc1 1.0
# CCC(C)OS(=O)(=O)c1ccc(C)cc1.[Na+].[Br-]>>CCC(C)Br CCC(C)(=O)O.CC(O)c1ccccc1 0
# OC1CCCCCCC1>OS(O)(=O)=O.O=[Cr](=O)=O>O=C1CCCCCCC1 O=C1CCCCCCC1 1.0
# OCC1CCCC1>[O-][Cr](Cl)(=O)=O.c1cc[nH+]cc1>O=CC1CCCC1 O=C(O)C1CCCC1 0.596153846154
# OCC1CCCC1>OS(O)(=O)=O.[O-][Cr](=O)(=O)O[Cr]([O-])(=O)=O.[Na+].[Na+]>OC(=O)C1CCCC1 O=C(O)C1CCCC1 1.0
# OC1CCCC1.Cl>[Zn++].[Cl-].[Cl-]>ClC1CCCC1 OC1CCCC1 0.4375
# CCCCO.Br>>CCCCBr CCCCBr 1.0
# CC(C)(C)[O-].[K+].CI>>COC(C)(C)C CC(C)(C)OC 1.0
# [Na+].C[O-].CC(C)(C)I>>CO.CC(C)=C COC(C)(C)C 0.428571428571
# OC1CCCC1>OS(O)(=O)=O>C1CC=CC1 ClC1CCCC1 0.305555555556
# C1CC=CC1>O=[Os](=O)(=O)=O.O[I](=O)(=O)=O.O>[H]C(=O)CCCC([H])=O OC1CCCC1O 0.305555555556
# CC[O-].[Na+].CCCCBr>CCO>CCCCOCC CCCCOC1C 0
# data/problems/11-41.txt	8.87203523499	0.58944469882	5	2
# ---------------
# O=C1CCCCC1.CN>Cl>CN=C1CCCCC1 CN=C1CCCCC1 1.0
# O=C1CCCCC1.CO>Cl>COC1(CCCCC1)OC COC1(O)CCCCC1 0.907216494845
# O=C1CCCCC1.NO>Cl>ON=C1CCCCC1 ON=C1CCCCC1 1.0
# O=C1CCCCC1.OCCO>Cc1ccc(cc1)S(O)(=O)=O>C1COC2(CCCCC2)O1 C1CCC2(CC1)OCCO2 1.0
# O=C1CCCCC1.NNc1ccccc1>Cl>C1CCC(CC1)=NNc1ccccc1 c1ccc(NN=C2CCCCC2)cc1 1.0
# O=C1CCCCC1.[Mg+]c1ccccc1.[Br-]>>OC1(CCCCC1)c1ccccc1 OC1(c2ccccc2)CCCCC1 1.0
# O=C1CCCCC1.[Na+].C#[C-]>>OC1(CCCCC1)C#C NC1(O)CCCCC1 0.516853932584
# O=C1CCCCC1>[K+].NN.[OH-]>C1CCCCC1 C1CCCCC1 1.0
# O=C1CCCCC1.C=P(c1ccccc1)(c1ccccc1)c1ccccc1>>C=C1CCCCC1 C=C(Cc1ccccc1)=C1CCCCC1 0
# O=C1CCCCC1.[Na+].[C-]#N>>OC1(CCCCC1)C#N N#CC1(O)CCCCC1 1.0
# OC1(CCCCC1)C#N.O>Cl>OC(=O)C1(O)CCCCC1 N=C(O)C1(CCCCC2CO2)C 0
# data/problems/18-56.txt	5.64648598101	0.765824584312	7	2
# ---------------
# ClC(=O)c1ccccc1.OC1CCCCC1>>O=C(OC1CCCCC1)c1ccccc1 O=C(OCC1CCCCC1)c1ccccc1 0.782426778243
# COC(=O)C1CCCCC1.CN>>CNC(=O)C1CCCCC1 COC(=O)C1CCCCC1 0.423312883436
# ClC(=O)c1ccccc1.C1CCNC1>>O=C(N1CCCC1)c1ccccc1 C1CCNC(=O)c1ccccc1 0
# O=C1CCCC(=O)O1.NC1CCCCC1>>OC(=O)CCCC(=O)NC1CCCCC1 O=C(CCCCCO)NC1CCCC1 0.802816901408
# CCOC(=O)c1ccccc1>[Al+3].[H-].[H-].[H-].[H-].[Li+]>OCc1ccccc1 CCO.OCc1ccccc1 0.944444444444
# O=C1CCCCN1>[Al+3].[H-].[H-].[H-].[H-].[Li+]>C1CCNCC1 C1CCCNC1 1.0
# O=C1CCCCCO1.[Na+].C[O-]>CO>OCCCCCC(O)=O COC(=O)CCCCCO 0.733333333333
# O=C1CCCCO1.[Mg+]c1ccccc1.[Br-]>>OCCCCC(O)(c1ccccc1)c1ccccc1 OCCCCC(O)(c1ccccc1)c1ccccc1 1.0
# N#CC1CCCC1.C[Mg+].[I-]>>CC(=O)C1CCCC1 CC(=O)C1CCCC1 1.0
# O=C1CCCCCN1.O>[OH-].[Na+]>NCCCCCC(O)=O NCCCCCC(=O)O 1.0
# CC(CC(N)=O)c1ccccc1>[Na+].BrBr.[OH-]>CC(CN)c1ccccc1 CC(CN1)Cc1ccccc1 0
# O=C1CCCCC1.OCCO>Cl>C1COC2(CCCCC2)O1 C1CCC2(CC1)OCCO2 1.0
# O=C1CCCCO1.OCCO>Cl>OCCCCC(=O)OCCO COCCCC(=O)OC1CC1 0.550847457627
# data/problems/21-50.txt	8.0618322567	0.710552446038	5	2
# ---------------
# C=CC=C.OC(=O)C=C>>OC(=O)C1CCC=CC1 C=C(C)OCC 0.344262295082
# C1CC=CC=C1.COC(=O)C#C>>COC(=O)C1=CC2CCC1C=C2 CC(=O)OC(=O)CC1CCC1 0.493212669683
# C1C=CC=C1.OC(=O)C=C>>OC(=O)C1CC2CC1C=C2 CC(C)=OCC1CC1 0
# CO\C=C\C=C.[H]C(=O)C=C>>[H]C(=O)C1CCC=CC1OC C=C(C)OCC 0.322580645161
# C\C=C\C=C\C.N#C\C=C/C#N>>CC1C=CC(C)C(C#N)C1C#N CCC(C)=NCCC(C)=O 0.259259259259
# C\C=C/C=C\C.N#C\C=C/C#N>>CC1C=CC(C)C(C#N)C1C#N CCC(C)=NCCC(C)=O 0.259259259259
# data/problems/15-30.txt	21.4003211657	0.279762354741	0	1
# ---------------
# CCCC#C.Cl>>CCCC(C)(Cl)Cl CCCC(C)(Cl)Cl 1.0
# CCCC#C.[H][H]>[Ni]>CCCCC CCCCC 1.0
# CCCC#C.BrBr>>CCCC(Br)(Br)C(Br)Br CCCC(Br)(Br)C(Br)Br 1.0
# CCCC#C>[K+].[O-][Mn](=O)(=O)=O>CCCC(=O)C(O)=O CCCC(=O)C=O 0.595238095238
# CCCC#C>[Na+].[K+].[OH-].[O-][Mn](=O)(=O)=O>CCCC(O)=O CCCC(=O)O 1.0
# CCCC#C>N.[Na]>C=CCCC C=CCCC 1.0
# CCCC#C.O>[Hg++].OS(O)(=O)=O.[O-]S([O-])(=O)=O>CCCC(C)=O CCCC(C)=O 1.0
# CCCC#C.O>CC(C)C(C)BC(C)C(C)C.[OH-].[Na+].OO>CCCCC=O CCCCC(C)=O 0.708333333333
# data/problems/9-33.txt	2.40399896926	0.912946428571	6	0
# ---------------
# [Mg+]C1CCCCC1.[Br-].C=O>>OCC1CCCCC1 CC1(O)CCCCC1 0.616666666667
# [Mg+]C1CCCC1.[Cl-].CCCC(C)=O>>CCCC(C)(O)C1CCCC1 CCCC(C)(O)C1CCCC1 1.0
# CC(C)[Mg+].[I-].[H]C(=O)c1ccccc1>>CC(C)C(O)c1ccccc1 CC(C)c1ccccc1.CC(C)O 0.627659574468
# C[Mg+].[I-].OC1CCCC(=O)C1>>CC1(O)CCCC(O)C1 CC1(O)CCCC(C)C1 0.737373737374
# [H]C(=O)C1CCCC1>[Na+].[BH4-]>OCC1CCCC1 OCC1CCCC1 1.0
# [Mg+]c1ccccc1.[Br-].O=C(c1ccccc1)c1ccccc1>>OC(c1ccccc1)(c1ccccc1)c1ccccc1 OC(c1ccccc1)c1ccccc1 0.801418439716
# [Mg+]c1ccccc1.[Br-].COC(=O)C1CCCC1>>OC(C1CCCC1)(c1ccccc1)c1ccccc1 CO.OC(c1ccccc1)(c1ccccc1)C1CCCC1 1.0
# [Mg+]CC1CCCC1.[Cl-].ClC(=O)c1ccccc1>>OC(CC1CCCC1)(CC1CCCC1)c1ccccc1 OC(Cc1ccccc1)(c1ccccc1)C1CCCC1 0.574948665298
# COC(=O)CC1CCCC(=O)C1>[Na+].[BH4-]>COC(=O)CC1CCCC(O)C1 CO.O=CCC1CCCC1 0.422680412371
# COC(=O)CC1CCCC(=O)C1>[Al+3].[H-].[H-].[H-].[H-].[Li+]>OCCC1CCCC(O)C1 CO.OCCC1CCCC1 0.575757575758
# C1CCC2=CCCCC2C1.O>CC(=O)O[Hg]OC(C)=O.[BH4-].[Na+]>OC12CCCCC1CCCC2 OC12CCCCC1CCCC2 1.0
# C1CCC2=CCCCC2C1.O>B.C1CCOC1.OO.[Na+].[OH-]>OC1CCCC2CCCCC12 OC1CCCC2CCCCC12 1.0
# CCC\C=C\C>[O-][Mn](=O)(=O)=O.[K+].[Na+].[OH-]>CCCC(O)C(C)O CCCC(O)C(C)O 1.0
# CCC\C=C\C>[H]C(=O)OO.Cl>CCCC(O)C(C)O CCCC=OC1C 0
# CC[Cu-]CC.[Li+].CC\C=C\CBr>>CC\C=C\CC=C CCCC(CC)=CCC 0.375
# data/problems/10-38.txt	10.7982503688	0.715433671443	6	1
# ---------------
# CC=C(C)C.Br>COOC>CC(C)C(C)Br CC(C)C(C)Br 1.0
# CC=C1CCCC1.O>OS(O)(=O)=O>CCC1(O)CCCC1 CCC1(O)CCCC1 1.0
# CC(C)C=C.Br>>CC(C)C(C)Br CC(C)C(C)Br 1.0
# C=Cc1ccccc1.BrC(Br)Br>[Na+].[OH-]>BrC1(Br)CC1c1ccccc1 BrC1(Br)CC1c1ccccc1 1.0
# CC=CC.CO>Cl>CCC(C)OC CCC(C)OC 1.0
# CC=CC.BrBr>CO.[Li+].[Cl-]>CC(Br)C(C)Br CC(Br)C(C)Br 1.0
# c1ccccc1C=C.c1ccccc1C=C>Cl>CC(c1ccccc1)C=Cc2ccccc2 C=Cc1ccccc1=CC(C)c1ccccc1 0
# data/problems/8-48.txt	2.38319761784	0.857142857143	6	1
# ---------------
# data/problems/8-47.txt	1.07091126624	0.8975	13	1
# data/problems/9-34.txt	8.38281387964	0.659456509877	3	0
# data/problems/17-44.txt	10.7509029969	0.548331431676	2	1
# data/problems/11-41.txt	8.87203523499	0.58944469882	5	2
# data/problems/18-56.txt	5.64648598101	0.765824584312	7	2
# data/problems/21-50.txt	8.0618322567	0.710552446038	5	2
# data/problems/15-30.txt	21.4003211657	0.279762354741	0	1
# data/problems/9-33.txt	2.40399896926	0.912946428571	6	0
# data/problems/10-38.txt	10.7982503688	0.715433671443	6	1
# data/problems/8-48.txt	2.38319761784	0.857142857143	6	1

# %% [markdown]
# number, average loss(cross entropy), average tanimoto similarity, right, absolutely wrong
